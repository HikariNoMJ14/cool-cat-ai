# %%
import os
from glob import glob
from chord_extractor.extractors import Chordino
import music21

# %%
folder = "./data/Complete Examples Melodies"

files = [y for x in os.walk(folder) for y in glob(os.path.join(x[0], '*.mid'))]

# %%
files
# Out:
# ['./data/Complete Examples Melodies/Doug McKenzie/I Thought About You.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Alice In Wonderland.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Autumn Leaves.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Blue Room.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/But Beautiful.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Come Rain Or Come Shine (1).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Come Rain Or Come Shine (2).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Come Sunday.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Cry Me A River.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Dancing On The Ceiling.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Estate.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Have You Met Miss Jones (1).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Have You Met Miss Jones (2).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/I Concentrate On You.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/I Cover The Waterfront.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/I Love You.mid',
#  "./data/Complete Examples Melodies/Doug McKenzie/I'm Confessin' That I Love You.mid",
#  './data/Complete Examples Melodies/Doug McKenzie/In Your Own Sweet Way (1).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/In Your Own Sweet Way (2).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/In Your Own Sweet Way (3).mid',
#  "./data/Complete Examples Melodies/Doug McKenzie/Isn't It Romantic.mid",
#  "./data/Complete Examples Melodies/Doug McKenzie/It Don't Mean A Thing.mid",
#  './data/Complete Examples Melodies/Doug McKenzie/Just Friends (2).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Just The Way You Look Tonight.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Long Ago And Far Away.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Miyako.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Mood Indigo.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Moon River.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/My Funny Valentine.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/My One And Only Love.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/My Shining Hour (2).mid',
#  './data/Complete Examples Melodies/Doug McKenzie/My Ship.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Nardis.mid',
#  "./data/Complete Examples Melodies/Doug McKenzie/Peri's Scope.mid",
#  './data/Complete Examples Melodies/Doug McKenzie/Prelude To A Kiss.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Some Other Time.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Sophisticated Lady.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Spring Is Here.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Star Eyes.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Stella By Starlight.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Tea For Two.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/The Duke.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Yesterdays.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/You Are Too Beautiful.mid',
#  './data/Complete Examples Melodies/Doug McKenzie/Young And Foolish.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Nardis.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/April In Paris.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Autumn Leaves (1).mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Autumn Leaves (2).mid',
#  './data/Complete Examples Melodies/Jazz-Midi/But Beautiful.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Dancing On The Ceiling.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/East Of The Sun.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Eighty-One.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Happy Birthday.mid',
#  "./data/Complete Examples Melodies/Jazz-Midi/I Can't Give You Anything But Love.mid",
#  './data/Complete Examples Melodies/Jazz-Midi/I Concentrate On You.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/I Should Care.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/In A Sentimental Mood.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Just The Way You Look Tonight (2).mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Moon River.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/My Funny Valentine.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Night And Day.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Our Love Is Here To Stay.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/People.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Round Midnight.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Secret Love.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/September Song.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Since I Fell For You.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Strangers In The Night.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Sweet Georgia Brown.mid',
#  "./data/Complete Examples Melodies/Jazz-Midi/The Party's Over.mid",
#  './data/Complete Examples Melodies/Jazz-Midi/The Shadow Of Your Smile.mid',
#  "./data/Complete Examples Melodies/Jazz-Midi/They Can't Take That Away From Me (2).mid",
#  './data/Complete Examples Melodies/Jazz-Midi/When Your Lover Has Gone.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Yesterdays.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/You Are Too Beautiful.mid',
#  './data/Complete Examples Melodies/Jazz-Midi/Yours Is My Heart Alone.mid',
#  './data/Complete Examples Melodies/JazzPage/A Felicidade.mid',
#  './data/Complete Examples Melodies/JazzPage/All The Things You Are (1).mid',
#  './data/Complete Examples Melodies/JazzPage/Alone Together (2).mid',
#  './data/Complete Examples Melodies/JazzPage/Black Narcissus.mid',
#  './data/Complete Examples Melodies/JazzPage/Blue Monk.mid',
#  './data/Complete Examples Melodies/JazzPage/Come Rain Or Come Shine (2).mid',
#  './data/Complete Examples Melodies/JazzPage/Four On Six.mid',
#  './data/Complete Examples Melodies/JazzPage/Gentle Rain.mid',
#  './data/Complete Examples Melodies/JazzPage/Have You Met Miss Jones.mid',
#  './data/Complete Examples Melodies/JazzPage/How High The Moon.mid',
#  "./data/Complete Examples Melodies/JazzPage/I Didn't Know What Time It Was.mid",
#  './data/Complete Examples Melodies/JazzPage/I Got Rhythm (2).mid',
#  "./data/Complete Examples Melodies/JazzPage/I've Grown Accustomed To Her Face (1).mid",
#  "./data/Complete Examples Melodies/JazzPage/I've Grown Accustomed To Her Face.mid",
#  "./data/Complete Examples Melodies/JazzPage/Lulu's Back In Town.mid",
#  './data/Complete Examples Melodies/JazzPage/My Funny Valentine.mid',
#  './data/Complete Examples Melodies/JazzPage/Nardis (2).mid',
#  "./data/Complete Examples Melodies/JazzPage/Now's The Time.mid",
#  './data/Complete Examples Melodies/JazzPage/Old Devil Moon.mid',
#  './data/Complete Examples Melodies/JazzPage/Our Love Is Here To Stay (2).mid',
#  "./data/Complete Examples Melodies/JazzPage/Peri's Scope.mid",
#  './data/Complete Examples Melodies/JazzPage/Secret Love.mid',
#  './data/Complete Examples Melodies/JazzPage/Since I Fell For You.mid',
#  './data/Complete Examples Melodies/JazzPage/Straight, No Chaser (1).mid',
#  './data/Complete Examples Melodies/JazzPage/Straight, No Chaser.mid',
#  './data/Complete Examples Melodies/JazzPage/Tenderly.mid',
#  './data/Complete Examples Melodies/JazzPage/The Days Of Wine And Roses.mid',
#  './data/Complete Examples Melodies/JazzPage/The Man I Love.mid',
#  './data/Complete Examples Melodies/JazzPage/When Your Lover Has Gone.mid',
#  "./data/Complete Examples Melodies/MidKar/Ain't Misbehavin'.mid",
#  './data/Complete Examples Melodies/MidKar/All The Things You Are.mid',
#  './data/Complete Examples Melodies/MidKar/Bemsha Swing.mid',
#  './data/Complete Examples Melodies/MidKar/Black Narcissus.mid',
#  './data/Complete Examples Melodies/MidKar/Blue Room.mid',
#  "./data/Complete Examples Melodies/MidKar/C'est Magnifique.mid",
#  './data/Complete Examples Melodies/MidKar/Come Sunday.mid',
#  './data/Complete Examples Melodies/MidKar/Dearly Beloved.mid',
#  './data/Complete Examples Melodies/MidKar/Deep Purple.mid',
#  './data/Complete Examples Melodies/MidKar/Falling In Love With Love.mid',
#  "./data/Complete Examples Melodies/MidKar/Here's That Rainy Day.mid",
#  './data/Complete Examples Melodies/MidKar/How High The Moon.mid',
#  './data/Complete Examples Melodies/MidKar/I Cover The Waterfront.mid',
#  './data/Complete Examples Melodies/MidKar/I Thought About You.mid',
#  "./data/Complete Examples Melodies/MidKar/I'll Be Around.mid",
#  "./data/Complete Examples Melodies/MidKar/I'm Confessin' That I Love You.mid",
#  './data/Complete Examples Melodies/MidKar/Lady Is A Tramp.mid',
#  './data/Complete Examples Melodies/MidKar/Memories Of You.mid',
#  './data/Complete Examples Melodies/MidKar/Misty.mid',
#  './data/Complete Examples Melodies/MidKar/New York, New York.mid',
#  './data/Complete Examples Melodies/MidKar/Old Devil Moon.mid',
#  './data/Complete Examples Melodies/MidKar/Once In A While.mid',
#  './data/Complete Examples Melodies/MidKar/Side By Side.mid',
#  './data/Complete Examples Melodies/MidKar/Speak Low.mid',
#  "./data/Complete Examples Melodies/MidKar/Well, You Needn't.mid",
#  './data/Complete Examples Melodies/MidKar/When Sunny Gets Blue.mid',
#  "./data/Complete Examples Melodies/MidKar/You Don't Know What Love Is.mid",
#  "./data/Complete Examples Melodies/MidKar/You've Changed.mid",
#  './data/Complete Examples Melodies/MidKar/Young And Foolish.mid',
#  './data/Complete Examples Melodies/Oocities/Alone Together (2).mid',
#  './data/Complete Examples Melodies/Oocities/Come Rain Or Come Shine.mid',
#  './data/Complete Examples Melodies/Oocities/Honeysuckle Rose.mid',
#  './data/Complete Examples Melodies/Oocities/My Favorite Things.mid',
#  './data/Complete Examples Melodies/Oocities/Nardis.mid',
#  './data/Complete Examples Melodies/Oocities/New York, New York (1).mid',
#  './data/Complete Examples Melodies/Oocities/Night And Day.mid',
#  './data/Complete Examples Melodies/Oocities/The Days Of Wine And Roses.mid',
#  './data/Complete Examples Melodies/Oocities/When Sunny Gets Blue.mid',
#  './data/Complete Examples Melodies/Oocities/You Took Advantage Of Me.mid',
#  "./data/Complete Examples Melodies/Oocities/You've Changed.mid",
#  './data/Complete Examples Melodies/Real Book/A Felicidade.mid',
#  './data/Complete Examples Melodies/Real Book/A Foggy Day.mid',
#  './data/Complete Examples Melodies/Real Book/A Night In Tunisia.mid',
#  './data/Complete Examples Melodies/Real Book/Accentuate The Positive.mid',
#  './data/Complete Examples Melodies/Real Book/Afro Blue.mid',
#  "./data/Complete Examples Melodies/Real Book/After You've Gone.mid",
#  "./data/Complete Examples Melodies/Real Book/Ain't Misbehavin'.mid",
#  './data/Complete Examples Melodies/Real Book/Airegin.mid',
#  './data/Complete Examples Melodies/Real Book/Alice In Wonderland.mid',
#  './data/Complete Examples Melodies/Real Book/All Blues.mid',
#  './data/Complete Examples Melodies/Real Book/All Of Me.mid',
#  './data/Complete Examples Melodies/Real Book/All Or Nothing At All.mid',
#  './data/Complete Examples Melodies/Real Book/All The Things You Are.mid',
#  './data/Complete Examples Melodies/Real Book/Alone Together.mid',
#  './data/Complete Examples Melodies/Real Book/Another You.mid',
#  './data/Complete Examples Melodies/Real Book/Anthropology.mid',
#  './data/Complete Examples Melodies/Real Book/April In Paris.mid',
#  './data/Complete Examples Melodies/Real Book/Autumn Leaves.mid',
#  "./data/Complete Examples Melodies/Real Book/Bags' Groove.mid",
#  './data/Complete Examples Melodies/Real Book/Beautiful Friendship.mid',
#  './data/Complete Examples Melodies/Real Book/Beautiful Love.mid',
#  './data/Complete Examples Melodies/Real Book/Bemsha Swing.mid',
#  "./data/Complete Examples Melodies/Real Book/Bessie's Blues.mid",
#  './data/Complete Examples Melodies/Real Book/Bewitched.mid',
#  './data/Complete Examples Melodies/Real Book/Black Narcissus.mid',
#  './data/Complete Examples Melodies/Real Book/Black Orpheus.mid',
#  './data/Complete Examples Melodies/Real Book/Blue In Green.mid',
#  './data/Complete Examples Melodies/Real Book/Blue Monk.mid',
#  './data/Complete Examples Melodies/Real Book/Blue Room.mid',
#  './data/Complete Examples Melodies/Real Book/Blue Train.mid',
#  './data/Complete Examples Melodies/Real Book/Blues For Alice.mid',
#  './data/Complete Examples Melodies/Real Book/But Beautiful.mid',
#  './data/Complete Examples Melodies/Real Book/But Not For Me.mid',
#  './data/Complete Examples Melodies/Real Book/Bye Bye Blackbird.mid',
#  './data/Complete Examples Melodies/Real Book/Christmas Song.mid',
#  './data/Complete Examples Melodies/Real Book/Come Rain Or Come Shine.mid',
#  './data/Complete Examples Melodies/Real Book/Come Sunday.mid',
#  './data/Complete Examples Melodies/Real Book/Cottontail.mid',
#  './data/Complete Examples Melodies/Real Book/Criss-Cross.mid',
#  './data/Complete Examples Melodies/Real Book/Cry Me A River.mid',
#  './data/Complete Examples Melodies/Real Book/Daahoud.mid',
#  './data/Complete Examples Melodies/Real Book/Dancing On The Ceiling.mid',
#  './data/Complete Examples Melodies/Real Book/Darn That Dream.mid',
#  './data/Complete Examples Melodies/Real Book/Dearly Beloved.mid',
#  './data/Complete Examples Melodies/Real Book/Deep Purple.mid',
#  "./data/Complete Examples Melodies/Real Book/Do Nothin' 'Til You Hear From Me.mid",
#  './data/Complete Examples Melodies/Real Book/Dolores.mid',
#  "./data/Complete Examples Melodies/Real Book/Don't Blame Me.mid",
#  './data/Complete Examples Melodies/Real Book/Donna Lee.mid',
#  './data/Complete Examples Melodies/Real Book/Doxy.mid',
#  './data/Complete Examples Melodies/Real Book/Eighty-One.mid',
#  './data/Complete Examples Melodies/Real Book/Embraceable You.mid',
#  './data/Complete Examples Melodies/Real Book/Esp.mid',
#  './data/Complete Examples Melodies/Real Book/Estate.mid',
#  './data/Complete Examples Melodies/Real Book/Falling Grace.mid',
#  './data/Complete Examples Melodies/Real Book/Falling In Love With Love.mid',
#  './data/Complete Examples Melodies/Real Book/Fly Me To The Moon.mid',
#  './data/Complete Examples Melodies/Real Book/Fools Rush In.mid',
#  './data/Complete Examples Melodies/Real Book/Footprints.mid',
#  './data/Complete Examples Melodies/Real Book/Four On Six.mid',
#  './data/Complete Examples Melodies/Real Book/Four.mid',
#  './data/Complete Examples Melodies/Real Book/Gentle Rain.mid',
#  "./data/Complete Examples Melodies/Real Book/Gettin' Sentimental Over You.mid",
#  './data/Complete Examples Melodies/Real Book/Giant Steps.mid',
#  './data/Complete Examples Melodies/Real Book/Girl Talk.mid',
#  './data/Complete Examples Melodies/Real Book/Give My Regards To Broadway.mid',
#  './data/Complete Examples Melodies/Real Book/Ask Me Now.mid',
#  "./data/Complete Examples Melodies/Real Book/C'est Magnifique.mid",
#  './data/Complete Examples Melodies/Real Book/East Of The Sun.mid',
#  './data/Complete Examples Melodies/Real Book/Good Bait.mid',
#  './data/Complete Examples Melodies/Real Book/I Should Care.mid',
#  './data/Complete Examples Melodies/Real Book/Israel.mid',
#  './data/Complete Examples Melodies/Real Book/Margie.mid',
#  './data/Complete Examples Melodies/Real Book/Nardis.mid',
#  './data/Complete Examples Melodies/Real Book/Polka Dots And Moonbeams.mid',
#  './data/Complete Examples Melodies/Real Book/Speak Low.mid',
#  './data/Complete Examples Melodies/Real Book/The Man I Love.mid',
#  "./data/Complete Examples Melodies/Real Book/Groovin' High.mid",
#  './data/Complete Examples Melodies/Real Book/Happy Birthday.mid',
#  './data/Complete Examples Melodies/Real Book/Have You Met Miss Jones.mid',
#  "./data/Complete Examples Melodies/Real Book/Here's That Rainy Day.mid",
#  './data/Complete Examples Melodies/Real Book/Honeysuckle Rose.mid',
#  './data/Complete Examples Melodies/Real Book/How High The Moon.mid',
#  './data/Complete Examples Melodies/Real Book/How Insensitive.mid',
#  "./data/Complete Examples Melodies/Real Book/I Can't Give You Anything But Love.mid",
#  './data/Complete Examples Melodies/Real Book/I Concentrate On You.mid',
#  './data/Complete Examples Melodies/Real Book/I Cover The Waterfront.mid',
#  "./data/Complete Examples Melodies/Real Book/I Didn't Know What Time It Was.mid",
#  "./data/Complete Examples Melodies/Real Book/I Don't Know Why.mid",
#  './data/Complete Examples Melodies/Real Book/I Got Rhythm.mid',
#  './data/Complete Examples Melodies/Real Book/I Hear A Rhapsody.mid',
#  './data/Complete Examples Melodies/Real Book/I Love You.mid',
#  './data/Complete Examples Melodies/Real Book/I Thought About You.mid',
#  './data/Complete Examples Melodies/Real Book/I Want To Be Happy.mid',
#  "./data/Complete Examples Melodies/Real Book/I Won't Dance.mid",
#  "./data/Complete Examples Melodies/Real Book/I'll Be Around.mid",
#  "./data/Complete Examples Melodies/Real Book/I'll Be Seeing You.mid",
#  "./data/Complete Examples Melodies/Real Book/I'll Remember April.mid",
#  "./data/Complete Examples Melodies/Real Book/I'm Confessin' That I Love You.mid",
#  "./data/Complete Examples Melodies/Real Book/I'm In The Mood For Love.mid",
#  "./data/Complete Examples Melodies/Real Book/I've Grown Accustomed To Her Face.mid",
#  './data/Complete Examples Melodies/Real Book/Imagination.mid',
#  './data/Complete Examples Melodies/Real Book/Impressions.mid',
#  './data/Complete Examples Melodies/Real Book/In A Mellow Tone.mid',
#  './data/Complete Examples Melodies/Real Book/In A Sentimental Mood.mid',
#  './data/Complete Examples Melodies/Real Book/In Your Own Sweet Way.mid',
#  './data/Complete Examples Melodies/Real Book/Invitation.mid',
#  "./data/Complete Examples Melodies/Real Book/Isn't It Romantic.mid",
#  "./data/Complete Examples Melodies/Real Book/It Don't Mean A Thing.mid",
#  "./data/Complete Examples Melodies/Real Book/It's All Right With Me.mid",
#  './data/Complete Examples Melodies/Real Book/Jordu.mid',
#  './data/Complete Examples Melodies/Real Book/Ju-Ju.mid',
#  './data/Complete Examples Melodies/Real Book/Just Friends.mid',
#  './data/Complete Examples Melodies/Real Book/Just The Way You Look Tonight.mid',
#  './data/Complete Examples Melodies/Real Book/Lady Is A Tramp.mid',
#  './data/Complete Examples Melodies/Real Book/Laura.mid',
#  './data/Complete Examples Melodies/Real Book/Lazybird.mid',
#  "./data/Complete Examples Melodies/Real Book/Let's Cool One.mid",
#  './data/Complete Examples Melodies/Real Book/Limehouse Blues.mid',
#  './data/Complete Examples Melodies/Real Book/Long Ago And Far Away.mid',
#  './data/Complete Examples Melodies/Real Book/Lullaby Of Birdland.mid',
#  "./data/Complete Examples Melodies/Real Book/Lulu's Back In Town.mid",
#  './data/Complete Examples Melodies/Real Book/Maiden Voyage.mid',
#  './data/Complete Examples Melodies/Real Book/Make Someone Happy.mid',
#  './data/Complete Examples Melodies/Real Book/Mean To Me.mid',
#  './data/Complete Examples Melodies/Real Book/Meditation.mid',
#  './data/Complete Examples Melodies/Real Book/Memories Of You.mid',
#  './data/Complete Examples Melodies/Real Book/Misty.mid',
#  './data/Complete Examples Melodies/Real Book/Miyako.mid',
#  './data/Complete Examples Melodies/Real Book/Mood Indigo.mid',
#  './data/Complete Examples Melodies/Real Book/Moon River.mid',
#  './data/Complete Examples Melodies/Real Book/Moonglow.mid',
#  './data/Complete Examples Melodies/Real Book/More.mid',
#  './data/Complete Examples Melodies/Real Book/My Favorite Things.mid',
#  './data/Complete Examples Melodies/Real Book/My Funny Valentine.mid',
#  './data/Complete Examples Melodies/Real Book/My Little Suede Shoes.mid',
#  './data/Complete Examples Melodies/Real Book/My One And Only Love.mid',
#  './data/Complete Examples Melodies/Real Book/My Romance.mid',
#  './data/Complete Examples Melodies/Real Book/My Shining Hour.mid',
#  './data/Complete Examples Melodies/Real Book/My Ship.mid',
#  './data/Complete Examples Melodies/Real Book/New York, New York.mid',
#  './data/Complete Examples Melodies/Real Book/Night And Day.mid',
#  "./data/Complete Examples Melodies/Real Book/Now's The Time.mid",
#  './data/Complete Examples Melodies/Real Book/Old Devil Moon.mid',
#  './data/Complete Examples Melodies/Real Book/Oleo.mid',
#  './data/Complete Examples Melodies/Real Book/On A Slow Boat To China.mid',
#  './data/Complete Examples Melodies/Real Book/Once In A While.mid',
#  './data/Complete Examples Melodies/Real Book/Once Upon A Summertime.mid',
#  './data/Complete Examples Melodies/Real Book/One Note Samba.mid',
#  './data/Complete Examples Melodies/Real Book/Ornithology.mid',
#  './data/Complete Examples Melodies/Real Book/Our Love Is Here To Stay.mid',
#  './data/Complete Examples Melodies/Real Book/Palladium.mid',
#  './data/Complete Examples Melodies/Real Book/Peace.mid',
#  './data/Complete Examples Melodies/Real Book/People.mid',
#  "./data/Complete Examples Melodies/Real Book/Peri's Scope.mid",
#  './data/Complete Examples Melodies/Real Book/Pick Yourself Up.mid',
#  './data/Complete Examples Melodies/Real Book/Prelude To A Kiss.mid',
#  './data/Complete Examples Melodies/Real Book/Recado Bossa Nova.mid',
#  './data/Complete Examples Melodies/Real Book/Reflections.mid',
#  './data/Complete Examples Melodies/Real Book/Round Midnight.mid',
#  './data/Complete Examples Melodies/Real Book/Satin Doll.mid',
#  './data/Complete Examples Melodies/Real Book/Secret Love.mid',
#  './data/Complete Examples Melodies/Real Book/September Song.mid',
#  './data/Complete Examples Melodies/Real Book/Shiny Stockings.mid',
#  './data/Complete Examples Melodies/Real Book/Side By Side.mid',
#  './data/Complete Examples Melodies/Real Book/Since I Fell For You.mid',
#  './data/Complete Examples Melodies/Real Book/So What.mid',
#  './data/Complete Examples Melodies/Real Book/Softly As In A Morning Sunrise.mid',
#  './data/Complete Examples Melodies/Real Book/Solar.mid',
#  './data/Complete Examples Melodies/Real Book/Some Other Time.mid',
#  './data/Complete Examples Melodies/Real Book/Someone To Watch Over Me.mid',
#  './data/Complete Examples Melodies/Real Book/Sophisticated Lady.mid',
#  './data/Complete Examples Melodies/Real Book/Speak No Evil.mid',
#  './data/Complete Examples Melodies/Real Book/Spring Is Here.mid',
#  './data/Complete Examples Melodies/Real Book/Star Eyes.mid',
#  './data/Complete Examples Melodies/Real Book/Stella By Starlight.mid',
#  './data/Complete Examples Melodies/Real Book/Straight, No Chaser.mid',
#  './data/Complete Examples Melodies/Real Book/Strangers In The Night.mid',
#  './data/Complete Examples Melodies/Real Book/Summertime.mid',
#  './data/Complete Examples Melodies/Real Book/Sweet Georgia Brown.mid',
#  "./data/Complete Examples Melodies/Real Book/Swingin' Shepherd Blues.mid",
#  './data/Complete Examples Melodies/Real Book/Take Me Out To The Ball Game.mid',
#  "./data/Complete Examples Melodies/Real Book/Takin' A Chance On Love.mid",
#  './data/Complete Examples Melodies/Real Book/Tea For Two.mid',
#  './data/Complete Examples Melodies/Real Book/Tenderly.mid',
#  './data/Complete Examples Melodies/Real Book/The Days Of Wine And Roses.mid',
#  './data/Complete Examples Melodies/Real Book/The Duke.mid',
#  './data/Complete Examples Melodies/Real Book/The More I See You.mid',
#  './data/Complete Examples Melodies/Real Book/The Nearness Of You.mid',
#  "./data/Complete Examples Melodies/Real Book/The Party's Over.mid",
#  './data/Complete Examples Melodies/Real Book/The Shadow Of Your Smile.mid',
#  "./data/Complete Examples Melodies/Real Book/They Can't Take That Away From Me.mid",
#  './data/Complete Examples Melodies/Real Book/Watermelon Man.mid',
#  './data/Complete Examples Melodies/Real Book/Wave.mid',
#  "./data/Complete Examples Melodies/Real Book/We'll Be Together Again.mid",
#  "./data/Complete Examples Melodies/Real Book/Well, You Needn't.mid",
#  "./data/Complete Examples Melodies/Real Book/What's New.mid",
#  './data/Complete Examples Melodies/Real Book/When I Fall In Love.mid',
#  './data/Complete Examples Melodies/Real Book/When Sunny Gets Blue.mid',
#  './data/Complete Examples Melodies/Real Book/When Your Lover Has Gone.mid',
#  './data/Complete Examples Melodies/Real Book/Yesterdays.mid',
#  './data/Complete Examples Melodies/Real Book/You Are Too Beautiful.mid',
#  "./data/Complete Examples Melodies/Real Book/You Don't Know What Love Is.mid",
#  './data/Complete Examples Melodies/Real Book/You Took Advantage Of Me.mid',
#  "./data/Complete Examples Melodies/Real Book/You've Changed.mid",
#  './data/Complete Examples Melodies/Real Book/Young And Foolish.mid',
#  './data/Complete Examples Melodies/Real Book/Yours Is My Heart Alone.mid',
#  './data/Complete Examples Melodies/Weimar DB/Art Pepper - Anthropology.mid',
#  './data/Complete Examples Melodies/Weimar DB/Art Pepper - In A Mellow Tone.mid',
#  './data/Complete Examples Melodies/Weimar DB/Ben Webster - Bye Bye Blackbird.mid',
#  './data/Complete Examples Melodies/Weimar DB/Ben Webster - Night And Day.mid',
#  './data/Complete Examples Melodies/Weimar DB/Benny Carter - Just Friends.mid',
#  './data/Complete Examples Melodies/Weimar DB/Benny Carter - Long Ago And Far Away (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/Benny Carter - Long Ago And Far Away (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/Bix Beiderbecke - Margie.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Bob Berg - I Didn't Know What Time It Was.mid",
#  './data/Complete Examples Melodies/Weimar DB/Branford Marsalis - The Nearness Of You.mid',
#  './data/Complete Examples Melodies/Weimar DB/Cannonball Adderley - So What.mid',
#  './data/Complete Examples Melodies/Weimar DB/Cannonball Adderley - Star Eyes.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - Blues For Alice.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - Donna Lee.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - Embraceable You.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - My Little Suede Shoes.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - Ornithology.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Parker - Star Eyes.mid',
#  './data/Complete Examples Melodies/Weimar DB/Charlie Shavers - Limehouse Blues.mid',
#  './data/Complete Examples Melodies/Weimar DB/Chet Baker - Just Friends.mid',
#  './data/Complete Examples Melodies/Weimar DB/Chet Baker - Long Ago And Far Away.mid',
#  './data/Complete Examples Melodies/Weimar DB/Chris Potter - Anthropology.mid',
#  './data/Complete Examples Melodies/Weimar DB/Chris Potter - In A Sentimental Mood.mid',
#  './data/Complete Examples Melodies/Weimar DB/Clifford Brown - A Night In Tunisia.mid',
#  './data/Complete Examples Melodies/Weimar DB/Clifford Brown - Daahoud.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Clifford Brown - I'll Remember April (1).mid",
#  "./data/Complete Examples Melodies/Weimar DB/Clifford Brown - I'll Remember April (2).mid",
#  './data/Complete Examples Melodies/Weimar DB/Coleman Hawkins - Sophisticated Lady.mid',
#  './data/Complete Examples Melodies/Weimar DB/Curtis Fuller - Blue Train.mid',
#  './data/Complete Examples Melodies/Weimar DB/David Liebman - Secret Love.mid',
#  './data/Complete Examples Melodies/Weimar DB/David Liebman - Softly As In A Morning Sunrise.mid',
#  './data/Complete Examples Melodies/Weimar DB/David Murray - Ask Me Now.mid',
#  './data/Complete Examples Melodies/Weimar DB/Dickie Wells - I Got Rhythm.mid',
#  './data/Complete Examples Melodies/Weimar DB/Dizzy Gillespie - Anthropology.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Dizzy Gillespie - Groovin' High.mid",
#  './data/Complete Examples Melodies/Weimar DB/Don Ellis - I Love You.mid',
#  './data/Complete Examples Melodies/Weimar DB/Fats Navarro - Good Bait (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/Fats Navarro - Good Bait (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/Freddie Hubbard - Maiden Voyage.mid',
#  './data/Complete Examples Melodies/Weimar DB/Freddie Hubbard - Speak No Evil.mid',
#  './data/Complete Examples Melodies/Weimar DB/George Coleman - Maiden Voyage.mid',
#  './data/Complete Examples Melodies/Weimar DB/J J Johnson - My Funny Valentine.mid',
#  './data/Complete Examples Melodies/Weimar DB/J J Johnson - Yesterdays.mid',
#  "./data/Complete Examples Melodies/Weimar DB/John Coltrane - Bessie's Blues.mid",
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Blue Train.mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Giant Steps (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Giant Steps (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Impressions (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Impressions.mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - My Favorite Things (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - My Favorite Things (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - Oleo.mid',
#  './data/Complete Examples Melodies/Weimar DB/John Coltrane - So What.mid',
#  './data/Complete Examples Melodies/Weimar DB/Johnny Dodds - Once In A While.mid',
#  './data/Complete Examples Melodies/Weimar DB/Lee Konitz - All The Things You Are.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Charlie Parker - Don't Blame Me.mid",
#  './data/Complete Examples Melodies/Weimar DB/Clifford Brown - Jordu.mid',
#  './data/Complete Examples Melodies/Weimar DB/Herbie Hancock - Dolores.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Lee Konitz - I'll Remember April.mid",
#  './data/Complete Examples Melodies/Weimar DB/Milt Jackson - Bemsha Swing.mid',
#  './data/Complete Examples Melodies/Weimar DB/Sonny Rollins - Airegin.mid',
#  './data/Complete Examples Melodies/Weimar DB/Lee Konitz - Mean To Me.mid',
#  './data/Complete Examples Melodies/Weimar DB/Lee Morgan - Blue Train.mid',
#  './data/Complete Examples Melodies/Weimar DB/Lionel Hampton - Memories Of You.mid',
#  './data/Complete Examples Melodies/Weimar DB/Louis Armstrong - Once In A While.mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - Airegin.mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - Dolores.mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - E.S.P..mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - Eighty-One.mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - Oleo (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - Oleo (2).mid',
#  './data/Complete Examples Melodies/Weimar DB/Miles Davis - So What.mid',
#  './data/Complete Examples Melodies/Weimar DB/Milt Jackson - All The Things You Are.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Milt Jackson - Bags' Groove.mid",
#  './data/Complete Examples Melodies/Weimar DB/Milt Jackson - Softly As In A Morning Sunrise.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Milt Jackson - What's New.mid",
#  './data/Complete Examples Melodies/Weimar DB/Ornette Coleman - Peace.mid',
#  './data/Complete Examples Melodies/Weimar DB/Pat Metheny - All The Things You Are.mid',
#  './data/Complete Examples Melodies/Weimar DB/Paul Desmond - Alone Together.mid',
#  './data/Complete Examples Melodies/Weimar DB/Pepper Adams - A Night In Tunisia.mid',
#  './data/Complete Examples Melodies/Weimar DB/Pepper Adams - How High The Moon.mid',
#  './data/Complete Examples Melodies/Weimar DB/Phil Woods - Cottontail.mid',
#  './data/Complete Examples Melodies/Weimar DB/Phil Woods - Honeysuckle Rose.mid',
#  './data/Complete Examples Melodies/Weimar DB/Phil Woods - On A Slow Boat To China.mid',
#  './data/Complete Examples Melodies/Weimar DB/Red Garland - Oleo.mid',
#  './data/Complete Examples Melodies/Weimar DB/Sidney Bechet - Limehouse Blues.mid',
#  './data/Complete Examples Melodies/Weimar DB/Sidney Bechet - Summertime.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Sonny Rollins - I'll Remember April.mid",
#  './data/Complete Examples Melodies/Weimar DB/Stan Getz - My Funny Valentine.mid',
#  './data/Complete Examples Melodies/Weimar DB/Steve Lacy - Alone Together.mid',
#  './data/Complete Examples Melodies/Weimar DB/Steve Lacy - Ask Me Now.mid',
#  "./data/Complete Examples Melodies/Weimar DB/Steve Lacy - Let's Cool One.mid",
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - Dolores.mid',
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - E.S.P..mid',
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - Eighty-One.mid',
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - Footprints.mid',
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - Ju-Ju.mid',
#  './data/Complete Examples Melodies/Weimar DB/Wayne Shorter - Speak No Evil.mid',
#  './data/Complete Examples Melodies/Weimar DB/Woody Shaw - Imagination.mid',
#  './data/Complete Examples Melodies/Weimar DB/Wynton Marsalis - April In Paris.mid',
#  './data/Complete Examples Melodies/Weimar DB/Zoot Sims - All The Things You Are.mid',
#  './data/Complete Examples Melodies/Weimar DB/Zoot Sims - Night And Day (1).mid',
#  './data/Complete Examples Melodies/Weimar DB/Zoot Sims - Night And Day (2).mid']

# %%
orig_files = [(f.split('/')[-1], f.split('/')[-2]) for f in files if 'Real Book' in f]
len(orig_files)
# Out:
# 207

# %%
orig_files
# Out:
# [('A Felicidade.mid', 'Real Book'),
#  ('A Foggy Day.mid', 'Real Book'),
#  ('A Night In Tunisia.mid', 'Real Book'),
#  ('Accentuate The Positive.mid', 'Real Book'),
#  ('Afro Blue.mid', 'Real Book'),
#  ("After You've Gone.mid", 'Real Book'),
#  ("Ain't Misbehavin'.mid", 'Real Book'),
#  ('Airegin.mid', 'Real Book'),
#  ('Alice In Wonderland.mid', 'Real Book'),
#  ('All Blues.mid', 'Real Book'),
#  ('All Of Me.mid', 'Real Book'),
#  ('All Or Nothing At All.mid', 'Real Book'),
#  ('All The Things You Are.mid', 'Real Book'),
#  ('Alone Together.mid', 'Real Book'),
#  ('Another You.mid', 'Real Book'),
#  ('Anthropology.mid', 'Real Book'),
#  ('April In Paris.mid', 'Real Book'),
#  ('Autumn Leaves.mid', 'Real Book'),
#  ("Bags' Groove.mid", 'Real Book'),
#  ('Beautiful Friendship.mid', 'Real Book'),
#  ('Beautiful Love.mid', 'Real Book'),
#  ('Bemsha Swing.mid', 'Real Book'),
#  ("Bessie's Blues.mid", 'Real Book'),
#  ('Bewitched.mid', 'Real Book'),
#  ('Black Narcissus.mid', 'Real Book'),
#  ('Black Orpheus.mid', 'Real Book'),
#  ('Blue In Green.mid', 'Real Book'),
#  ('Blue Monk.mid', 'Real Book'),
#  ('Blue Room.mid', 'Real Book'),
#  ('Blue Train.mid', 'Real Book'),
#  ('Blues For Alice.mid', 'Real Book'),
#  ('But Beautiful.mid', 'Real Book'),
#  ('But Not For Me.mid', 'Real Book'),
#  ('Bye Bye Blackbird.mid', 'Real Book'),
#  ('Christmas Song.mid', 'Real Book'),
#  ('Come Rain Or Come Shine.mid', 'Real Book'),
#  ('Come Sunday.mid', 'Real Book'),
#  ('Cottontail.mid', 'Real Book'),
#  ('Criss-Cross.mid', 'Real Book'),
#  ('Cry Me A River.mid', 'Real Book'),
#  ('Daahoud.mid', 'Real Book'),
#  ('Dancing On The Ceiling.mid', 'Real Book'),
#  ('Darn That Dream.mid', 'Real Book'),
#  ('Dearly Beloved.mid', 'Real Book'),
#  ('Deep Purple.mid', 'Real Book'),
#  ("Do Nothin' 'Til You Hear From Me.mid", 'Real Book'),
#  ('Dolores.mid', 'Real Book'),
#  ("Don't Blame Me.mid", 'Real Book'),
#  ('Donna Lee.mid', 'Real Book'),
#  ('Doxy.mid', 'Real Book'),
#  ('Eighty-One.mid', 'Real Book'),
#  ('Embraceable You.mid', 'Real Book'),
#  ('Esp.mid', 'Real Book'),
#  ('Estate.mid', 'Real Book'),
#  ('Falling Grace.mid', 'Real Book'),
#  ('Falling In Love With Love.mid', 'Real Book'),
#  ('Fly Me To The Moon.mid', 'Real Book'),
#  ('Fools Rush In.mid', 'Real Book'),
#  ('Footprints.mid', 'Real Book'),
#  ('Four On Six.mid', 'Real Book'),
#  ('Four.mid', 'Real Book'),
#  ('Gentle Rain.mid', 'Real Book'),
#  ("Gettin' Sentimental Over You.mid", 'Real Book'),
#  ('Giant Steps.mid', 'Real Book'),
#  ('Girl Talk.mid', 'Real Book'),
#  ('Give My Regards To Broadway.mid', 'Real Book'),
#  ('Ask Me Now.mid', 'Real Book'),
#  ("C'est Magnifique.mid", 'Real Book'),
#  ('East Of The Sun.mid', 'Real Book'),
#  ('Good Bait.mid', 'Real Book'),
#  ('I Should Care.mid', 'Real Book'),
#  ('Israel.mid', 'Real Book'),
#  ('Margie.mid', 'Real Book'),
#  ('Nardis.mid', 'Real Book'),
#  ('Polka Dots And Moonbeams.mid', 'Real Book'),
#  ('Speak Low.mid', 'Real Book'),
#  ('The Man I Love.mid', 'Real Book'),
#  ("Groovin' High.mid", 'Real Book'),
#  ('Happy Birthday.mid', 'Real Book'),
#  ('Have You Met Miss Jones.mid', 'Real Book'),
#  ("Here's That Rainy Day.mid", 'Real Book'),
#  ('Honeysuckle Rose.mid', 'Real Book'),
#  ('How High The Moon.mid', 'Real Book'),
#  ('How Insensitive.mid', 'Real Book'),
#  ("I Can't Give You Anything But Love.mid", 'Real Book'),
#  ('I Concentrate On You.mid', 'Real Book'),
#  ('I Cover The Waterfront.mid', 'Real Book'),
#  ("I Didn't Know What Time It Was.mid", 'Real Book'),
#  ("I Don't Know Why.mid", 'Real Book'),
#  ('I Got Rhythm.mid', 'Real Book'),
#  ('I Hear A Rhapsody.mid', 'Real Book'),
#  ('I Love You.mid', 'Real Book'),
#  ('I Thought About You.mid', 'Real Book'),
#  ('I Want To Be Happy.mid', 'Real Book'),
#  ("I Won't Dance.mid", 'Real Book'),
#  ("I'll Be Around.mid", 'Real Book'),
#  ("I'll Be Seeing You.mid", 'Real Book'),
#  ("I'll Remember April.mid", 'Real Book'),
#  ("I'm Confessin' That I Love You.mid", 'Real Book'),
#  ("I'm In The Mood For Love.mid", 'Real Book'),
#  ("I've Grown Accustomed To Her Face.mid", 'Real Book'),
#  ('Imagination.mid', 'Real Book'),
#  ('Impressions.mid', 'Real Book'),
#  ('In A Mellow Tone.mid', 'Real Book'),
#  ('In A Sentimental Mood.mid', 'Real Book'),
#  ('In Your Own Sweet Way.mid', 'Real Book'),
#  ('Invitation.mid', 'Real Book'),
#  ("Isn't It Romantic.mid", 'Real Book'),
#  ("It Don't Mean A Thing.mid", 'Real Book'),
#  ("It's All Right With Me.mid", 'Real Book'),
#  ('Jordu.mid', 'Real Book'),
#  ('Ju-Ju.mid', 'Real Book'),
#  ('Just Friends.mid', 'Real Book'),
#  ('Just The Way You Look Tonight.mid', 'Real Book'),
#  ('Lady Is A Tramp.mid', 'Real Book'),
#  ('Laura.mid', 'Real Book'),
#  ('Lazybird.mid', 'Real Book'),
#  ("Let's Cool One.mid", 'Real Book'),
#  ('Limehouse Blues.mid', 'Real Book'),
#  ('Long Ago And Far Away.mid', 'Real Book'),
#  ('Lullaby Of Birdland.mid', 'Real Book'),
#  ("Lulu's Back In Town.mid", 'Real Book'),
#  ('Maiden Voyage.mid', 'Real Book'),
#  ('Make Someone Happy.mid', 'Real Book'),
#  ('Mean To Me.mid', 'Real Book'),
#  ('Meditation.mid', 'Real Book'),
#  ('Memories Of You.mid', 'Real Book'),
#  ('Misty.mid', 'Real Book'),
#  ('Miyako.mid', 'Real Book'),
#  ('Mood Indigo.mid', 'Real Book'),
#  ('Moon River.mid', 'Real Book'),
#  ('Moonglow.mid', 'Real Book'),
#  ('More.mid', 'Real Book'),
#  ('My Favorite Things.mid', 'Real Book'),
#  ('My Funny Valentine.mid', 'Real Book'),
#  ('My Little Suede Shoes.mid', 'Real Book'),
#  ('My One And Only Love.mid', 'Real Book'),
#  ('My Romance.mid', 'Real Book'),
#  ('My Shining Hour.mid', 'Real Book'),
#  ('My Ship.mid', 'Real Book'),
#  ('New York, New York.mid', 'Real Book'),
#  ('Night And Day.mid', 'Real Book'),
#  ("Now's The Time.mid", 'Real Book'),
#  ('Old Devil Moon.mid', 'Real Book'),
#  ('Oleo.mid', 'Real Book'),
#  ('On A Slow Boat To China.mid', 'Real Book'),
#  ('Once In A While.mid', 'Real Book'),
#  ('Once Upon A Summertime.mid', 'Real Book'),
#  ('One Note Samba.mid', 'Real Book'),
#  ('Ornithology.mid', 'Real Book'),
#  ('Our Love Is Here To Stay.mid', 'Real Book'),
#  ('Palladium.mid', 'Real Book'),
#  ('Peace.mid', 'Real Book'),
#  ('People.mid', 'Real Book'),
#  ("Peri's Scope.mid", 'Real Book'),
#  ('Pick Yourself Up.mid', 'Real Book'),
#  ('Prelude To A Kiss.mid', 'Real Book'),
#  ('Recado Bossa Nova.mid', 'Real Book'),
#  ('Reflections.mid', 'Real Book'),
#  ('Round Midnight.mid', 'Real Book'),
#  ('Satin Doll.mid', 'Real Book'),
#  ('Secret Love.mid', 'Real Book'),
#  ('September Song.mid', 'Real Book'),
#  ('Shiny Stockings.mid', 'Real Book'),
#  ('Side By Side.mid', 'Real Book'),
#  ('Since I Fell For You.mid', 'Real Book'),
#  ('So What.mid', 'Real Book'),
#  ('Softly As In A Morning Sunrise.mid', 'Real Book'),
#  ('Solar.mid', 'Real Book'),
#  ('Some Other Time.mid', 'Real Book'),
#  ('Someone To Watch Over Me.mid', 'Real Book'),
#  ('Sophisticated Lady.mid', 'Real Book'),
#  ('Speak No Evil.mid', 'Real Book'),
#  ('Spring Is Here.mid', 'Real Book'),
#  ('Star Eyes.mid', 'Real Book'),
#  ('Stella By Starlight.mid', 'Real Book'),
#  ('Straight, No Chaser.mid', 'Real Book'),
#  ('Strangers In The Night.mid', 'Real Book'),
#  ('Summertime.mid', 'Real Book'),
#  ('Sweet Georgia Brown.mid', 'Real Book'),
#  ("Swingin' Shepherd Blues.mid", 'Real Book'),
#  ('Take Me Out To The Ball Game.mid', 'Real Book'),
#  ("Takin' A Chance On Love.mid", 'Real Book'),
#  ('Tea For Two.mid', 'Real Book'),
#  ('Tenderly.mid', 'Real Book'),
#  ('The Days Of Wine And Roses.mid', 'Real Book'),
#  ('The Duke.mid', 'Real Book'),
#  ('The More I See You.mid', 'Real Book'),
#  ('The Nearness Of You.mid', 'Real Book'),
#  ("The Party's Over.mid", 'Real Book'),
#  ('The Shadow Of Your Smile.mid', 'Real Book'),
#  ("They Can't Take That Away From Me.mid", 'Real Book'),
#  ('Watermelon Man.mid', 'Real Book'),
#  ('Wave.mid', 'Real Book'),
#  ("We'll Be Together Again.mid", 'Real Book'),
#  ("Well, You Needn't.mid", 'Real Book'),
#  ("What's New.mid", 'Real Book'),
#  ('When I Fall In Love.mid', 'Real Book'),
#  ('When Sunny Gets Blue.mid', 'Real Book'),
#  ('When Your Lover Has Gone.mid', 'Real Book'),
#  ('Yesterdays.mid', 'Real Book'),
#  ('You Are Too Beautiful.mid', 'Real Book'),
#  ("You Don't Know What Love Is.mid", 'Real Book'),
#  ('You Took Advantage Of Me.mid', 'Real Book'),
#  ("You've Changed.mid", 'Real Book'),
#  ('Young And Foolish.mid', 'Real Book'),
#  ('Yours Is My Heart Alone.mid', 'Real Book')]

# %%
impro_files = [(f.split('/')[-1], f.split('/')[-2]) for f in files if 'Real Book' not in f]
len(impro_files)
# Out:
# 249

# %%
impro_files.sort()
impro_files
# Out:
# [('A Felicidade.mid', 'JazzPage'),
#  ("Ain't Misbehavin'.mid", 'MidKar'),
#  ('Alice In Wonderland.mid', 'Doug McKenzie'),
#  ('All The Things You Are (1).mid', 'JazzPage'),
#  ('All The Things You Are.mid', 'MidKar'),
#  ('Alone Together (2).mid', 'JazzPage'),
#  ('Alone Together (2).mid', 'Oocities'),
#  ('April In Paris.mid', 'Jazz-Midi'),
#  ('Art Pepper - Anthropology.mid', 'Weimar DB'),
#  ('Art Pepper - In A Mellow Tone.mid', 'Weimar DB'),
#  ('Autumn Leaves (1).mid', 'Jazz-Midi'),
#  ('Autumn Leaves (2).mid', 'Jazz-Midi'),
#  ('Autumn Leaves.mid', 'Doug McKenzie'),
#  ('Bemsha Swing.mid', 'MidKar'),
#  ('Ben Webster - Bye Bye Blackbird.mid', 'Weimar DB'),
#  ('Ben Webster - Night And Day.mid', 'Weimar DB'),
#  ('Benny Carter - Just Friends.mid', 'Weimar DB'),
#  ('Benny Carter - Long Ago And Far Away (1).mid', 'Weimar DB'),
#  ('Benny Carter - Long Ago And Far Away (2).mid', 'Weimar DB'),
#  ('Bix Beiderbecke - Margie.mid', 'Weimar DB'),
#  ('Black Narcissus.mid', 'JazzPage'),
#  ('Black Narcissus.mid', 'MidKar'),
#  ('Blue Monk.mid', 'JazzPage'),
#  ('Blue Room.mid', 'Doug McKenzie'),
#  ('Blue Room.mid', 'MidKar'),
#  ("Bob Berg - I Didn't Know What Time It Was.mid", 'Weimar DB'),
#  ('Branford Marsalis - The Nearness Of You.mid', 'Weimar DB'),
#  ('But Beautiful.mid', 'Doug McKenzie'),
#  ('But Beautiful.mid', 'Jazz-Midi'),
#  ("C'est Magnifique.mid", 'MidKar'),
#  ('Cannonball Adderley - So What.mid', 'Weimar DB'),
#  ('Cannonball Adderley - Star Eyes.mid', 'Weimar DB'),
#  ('Charlie Parker - Blues For Alice.mid', 'Weimar DB'),
#  ("Charlie Parker - Don't Blame Me.mid", 'Weimar DB'),
#  ('Charlie Parker - Donna Lee.mid', 'Weimar DB'),
#  ('Charlie Parker - Embraceable You.mid', 'Weimar DB'),
#  ('Charlie Parker - My Little Suede Shoes.mid', 'Weimar DB'),
#  ('Charlie Parker - Ornithology.mid', 'Weimar DB'),
#  ('Charlie Parker - Star Eyes.mid', 'Weimar DB'),
#  ('Charlie Shavers - Limehouse Blues.mid', 'Weimar DB'),
#  ('Chet Baker - Just Friends.mid', 'Weimar DB'),
#  ('Chet Baker - Long Ago And Far Away.mid', 'Weimar DB'),
#  ('Chris Potter - Anthropology.mid', 'Weimar DB'),
#  ('Chris Potter - In A Sentimental Mood.mid', 'Weimar DB'),
#  ('Clifford Brown - A Night In Tunisia.mid', 'Weimar DB'),
#  ('Clifford Brown - Daahoud.mid', 'Weimar DB'),
#  ("Clifford Brown - I'll Remember April (1).mid", 'Weimar DB'),
#  ("Clifford Brown - I'll Remember April (2).mid", 'Weimar DB'),
#  ('Clifford Brown - Jordu.mid', 'Weimar DB'),
#  ('Coleman Hawkins - Sophisticated Lady.mid', 'Weimar DB'),
#  ('Come Rain Or Come Shine (1).mid', 'Doug McKenzie'),
#  ('Come Rain Or Come Shine (2).mid', 'Doug McKenzie'),
#  ('Come Rain Or Come Shine (2).mid', 'JazzPage'),
#  ('Come Rain Or Come Shine.mid', 'Oocities'),
#  ('Come Sunday.mid', 'Doug McKenzie'),
#  ('Come Sunday.mid', 'MidKar'),
#  ('Cry Me A River.mid', 'Doug McKenzie'),
#  ('Curtis Fuller - Blue Train.mid', 'Weimar DB'),
#  ('Dancing On The Ceiling.mid', 'Doug McKenzie'),
#  ('Dancing On The Ceiling.mid', 'Jazz-Midi'),
#  ('David Liebman - Secret Love.mid', 'Weimar DB'),
#  ('David Liebman - Softly As In A Morning Sunrise.mid', 'Weimar DB'),
#  ('David Murray - Ask Me Now.mid', 'Weimar DB'),
#  ('Dearly Beloved.mid', 'MidKar'),
#  ('Deep Purple.mid', 'MidKar'),
#  ('Dickie Wells - I Got Rhythm.mid', 'Weimar DB'),
#  ('Dizzy Gillespie - Anthropology.mid', 'Weimar DB'),
#  ("Dizzy Gillespie - Groovin' High.mid", 'Weimar DB'),
#  ('Don Ellis - I Love You.mid', 'Weimar DB'),
#  ('East Of The Sun.mid', 'Jazz-Midi'),
#  ('Eighty-One.mid', 'Jazz-Midi'),
#  ('Estate.mid', 'Doug McKenzie'),
#  ('Falling In Love With Love.mid', 'MidKar'),
#  ('Fats Navarro - Good Bait (1).mid', 'Weimar DB'),
#  ('Fats Navarro - Good Bait (2).mid', 'Weimar DB'),
#  ('Four On Six.mid', 'JazzPage'),
#  ('Freddie Hubbard - Maiden Voyage.mid', 'Weimar DB'),
#  ('Freddie Hubbard - Speak No Evil.mid', 'Weimar DB'),
#  ('Gentle Rain.mid', 'JazzPage'),
#  ('George Coleman - Maiden Voyage.mid', 'Weimar DB'),
#  ('Happy Birthday.mid', 'Jazz-Midi'),
#  ('Have You Met Miss Jones (1).mid', 'Doug McKenzie'),
#  ('Have You Met Miss Jones (2).mid', 'Doug McKenzie'),
#  ('Have You Met Miss Jones.mid', 'JazzPage'),
#  ('Herbie Hancock - Dolores.mid', 'Weimar DB'),
#  ("Here's That Rainy Day.mid", 'MidKar'),
#  ('Honeysuckle Rose.mid', 'Oocities'),
#  ('How High The Moon.mid', 'JazzPage'),
#  ('How High The Moon.mid', 'MidKar'),
#  ("I Can't Give You Anything But Love.mid", 'Jazz-Midi'),
#  ('I Concentrate On You.mid', 'Doug McKenzie'),
#  ('I Concentrate On You.mid', 'Jazz-Midi'),
#  ('I Cover The Waterfront.mid', 'Doug McKenzie'),
#  ('I Cover The Waterfront.mid', 'MidKar'),
#  ("I Didn't Know What Time It Was.mid", 'JazzPage'),
#  ('I Got Rhythm (2).mid', 'JazzPage'),
#  ('I Love You.mid', 'Doug McKenzie'),
#  ('I Should Care.mid', 'Jazz-Midi'),
#  ('I Thought About You.mid', 'Doug McKenzie'),
#  ('I Thought About You.mid', 'MidKar'),
#  ("I'll Be Around.mid", 'MidKar'),
#  ("I'm Confessin' That I Love You.mid", 'Doug McKenzie'),
#  ("I'm Confessin' That I Love You.mid", 'MidKar'),
#  ("I've Grown Accustomed To Her Face (1).mid", 'JazzPage'),
#  ("I've Grown Accustomed To Her Face.mid", 'JazzPage'),
#  ('In A Sentimental Mood.mid', 'Jazz-Midi'),
#  ('In Your Own Sweet Way (1).mid', 'Doug McKenzie'),
#  ('In Your Own Sweet Way (2).mid', 'Doug McKenzie'),
#  ('In Your Own Sweet Way (3).mid', 'Doug McKenzie'),
#  ("Isn't It Romantic.mid", 'Doug McKenzie'),
#  ("It Don't Mean A Thing.mid", 'Doug McKenzie'),
#  ('J J Johnson - My Funny Valentine.mid', 'Weimar DB'),
#  ('J J Johnson - Yesterdays.mid', 'Weimar DB'),
#  ("John Coltrane - Bessie's Blues.mid", 'Weimar DB'),
#  ('John Coltrane - Blue Train.mid', 'Weimar DB'),
#  ('John Coltrane - Giant Steps (1).mid', 'Weimar DB'),
#  ('John Coltrane - Giant Steps (2).mid', 'Weimar DB'),
#  ('John Coltrane - Impressions (2).mid', 'Weimar DB'),
#  ('John Coltrane - Impressions.mid', 'Weimar DB'),
#  ('John Coltrane - My Favorite Things (1).mid', 'Weimar DB'),
#  ('John Coltrane - My Favorite Things (2).mid', 'Weimar DB'),
#  ('John Coltrane - Oleo.mid', 'Weimar DB'),
#  ('John Coltrane - So What.mid', 'Weimar DB'),
#  ('Johnny Dodds - Once In A While.mid', 'Weimar DB'),
#  ('Just Friends (2).mid', 'Doug McKenzie'),
#  ('Just The Way You Look Tonight (2).mid', 'Jazz-Midi'),
#  ('Just The Way You Look Tonight.mid', 'Doug McKenzie'),
#  ('Lady Is A Tramp.mid', 'MidKar'),
#  ('Lee Konitz - All The Things You Are.mid', 'Weimar DB'),
#  ("Lee Konitz - I'll Remember April.mid", 'Weimar DB'),
#  ('Lee Konitz - Mean To Me.mid', 'Weimar DB'),
#  ('Lee Morgan - Blue Train.mid', 'Weimar DB'),
#  ('Lionel Hampton - Memories Of You.mid', 'Weimar DB'),
#  ('Long Ago And Far Away.mid', 'Doug McKenzie'),
#  ('Louis Armstrong - Once In A While.mid', 'Weimar DB'),
#  ("Lulu's Back In Town.mid", 'JazzPage'),
#  ('Memories Of You.mid', 'MidKar'),
#  ('Miles Davis - Airegin.mid', 'Weimar DB'),
#  ('Miles Davis - Dolores.mid', 'Weimar DB'),
#  ('Miles Davis - E.S.P..mid', 'Weimar DB'),
#  ('Miles Davis - Eighty-One.mid', 'Weimar DB'),
#  ('Miles Davis - Oleo (1).mid', 'Weimar DB'),
#  ('Miles Davis - Oleo (2).mid', 'Weimar DB'),
#  ('Miles Davis - So What.mid', 'Weimar DB'),
#  ('Milt Jackson - All The Things You Are.mid', 'Weimar DB'),
#  ("Milt Jackson - Bags' Groove.mid", 'Weimar DB'),
#  ('Milt Jackson - Bemsha Swing.mid', 'Weimar DB'),
#  ('Milt Jackson - Softly As In A Morning Sunrise.mid', 'Weimar DB'),
#  ("Milt Jackson - What's New.mid", 'Weimar DB'),
#  ('Misty.mid', 'MidKar'),
#  ('Miyako.mid', 'Doug McKenzie'),
#  ('Mood Indigo.mid', 'Doug McKenzie'),
#  ('Moon River.mid', 'Doug McKenzie'),
#  ('Moon River.mid', 'Jazz-Midi'),
#  ('My Favorite Things.mid', 'Oocities'),
#  ('My Funny Valentine.mid', 'Doug McKenzie'),
#  ('My Funny Valentine.mid', 'Jazz-Midi'),
#  ('My Funny Valentine.mid', 'JazzPage'),
#  ('My One And Only Love.mid', 'Doug McKenzie'),
#  ('My Shining Hour (2).mid', 'Doug McKenzie'),
#  ('My Ship.mid', 'Doug McKenzie'),
#  ('Nardis (2).mid', 'JazzPage'),
#  ('Nardis.mid', 'Doug McKenzie'),
#  ('Nardis.mid', 'Jazz-Midi'),
#  ('Nardis.mid', 'Oocities'),
#  ('New York, New York (1).mid', 'Oocities'),
#  ('New York, New York.mid', 'MidKar'),
#  ('Night And Day.mid', 'Jazz-Midi'),
#  ('Night And Day.mid', 'Oocities'),
#  ("Now's The Time.mid", 'JazzPage'),
#  ('Old Devil Moon.mid', 'JazzPage'),
#  ('Old Devil Moon.mid', 'MidKar'),
#  ('Once In A While.mid', 'MidKar'),
#  ('Ornette Coleman - Peace.mid', 'Weimar DB'),
#  ('Our Love Is Here To Stay (2).mid', 'JazzPage'),
#  ('Our Love Is Here To Stay.mid', 'Jazz-Midi'),
#  ('Pat Metheny - All The Things You Are.mid', 'Weimar DB'),
#  ('Paul Desmond - Alone Together.mid', 'Weimar DB'),
#  ('People.mid', 'Jazz-Midi'),
#  ('Pepper Adams - A Night In Tunisia.mid', 'Weimar DB'),
#  ('Pepper Adams - How High The Moon.mid', 'Weimar DB'),
#  ("Peri's Scope.mid", 'Doug McKenzie'),
#  ("Peri's Scope.mid", 'JazzPage'),
#  ('Phil Woods - Cottontail.mid', 'Weimar DB'),
#  ('Phil Woods - Honeysuckle Rose.mid', 'Weimar DB'),
#  ('Phil Woods - On A Slow Boat To China.mid', 'Weimar DB'),
#  ('Prelude To A Kiss.mid', 'Doug McKenzie'),
#  ('Red Garland - Oleo.mid', 'Weimar DB'),
#  ('Round Midnight.mid', 'Jazz-Midi'),
#  ('Secret Love.mid', 'Jazz-Midi'),
#  ('Secret Love.mid', 'JazzPage'),
#  ('September Song.mid', 'Jazz-Midi'),
#  ('Side By Side.mid', 'MidKar'),
#  ('Sidney Bechet - Limehouse Blues.mid', 'Weimar DB'),
#  ('Sidney Bechet - Summertime.mid', 'Weimar DB'),
#  ('Since I Fell For You.mid', 'Jazz-Midi'),
#  ('Since I Fell For You.mid', 'JazzPage'),
#  ('Some Other Time.mid', 'Doug McKenzie'),
#  ('Sonny Rollins - Airegin.mid', 'Weimar DB'),
#  ("Sonny Rollins - I'll Remember April.mid", 'Weimar DB'),
#  ('Sophisticated Lady.mid', 'Doug McKenzie'),
#  ('Speak Low.mid', 'MidKar'),
#  ('Spring Is Here.mid', 'Doug McKenzie'),
#  ('Stan Getz - My Funny Valentine.mid', 'Weimar DB'),
#  ('Star Eyes.mid', 'Doug McKenzie'),
#  ('Stella By Starlight.mid', 'Doug McKenzie'),
#  ('Steve Lacy - Alone Together.mid', 'Weimar DB'),
#  ('Steve Lacy - Ask Me Now.mid', 'Weimar DB'),
#  ("Steve Lacy - Let's Cool One.mid", 'Weimar DB'),
#  ('Straight, No Chaser (1).mid', 'JazzPage'),
#  ('Straight, No Chaser.mid', 'JazzPage'),
#  ('Strangers In The Night.mid', 'Jazz-Midi'),
#  ('Sweet Georgia Brown.mid', 'Jazz-Midi'),
#  ('Tea For Two.mid', 'Doug McKenzie'),
#  ('Tenderly.mid', 'JazzPage'),
#  ('The Days Of Wine And Roses.mid', 'JazzPage'),
#  ('The Days Of Wine And Roses.mid', 'Oocities'),
#  ('The Duke.mid', 'Doug McKenzie'),
#  ('The Man I Love.mid', 'JazzPage'),
#  ("The Party's Over.mid", 'Jazz-Midi'),
#  ('The Shadow Of Your Smile.mid', 'Jazz-Midi'),
#  ("They Can't Take That Away From Me (2).mid", 'Jazz-Midi'),
#  ('Wayne Shorter - Dolores.mid', 'Weimar DB'),
#  ('Wayne Shorter - E.S.P..mid', 'Weimar DB'),
#  ('Wayne Shorter - Eighty-One.mid', 'Weimar DB'),
#  ('Wayne Shorter - Footprints.mid', 'Weimar DB'),
#  ('Wayne Shorter - Ju-Ju.mid', 'Weimar DB'),
#  ('Wayne Shorter - Speak No Evil.mid', 'Weimar DB'),
#  ("Well, You Needn't.mid", 'MidKar'),
#  ('When Sunny Gets Blue.mid', 'MidKar'),
#  ('When Sunny Gets Blue.mid', 'Oocities'),
#  ('When Your Lover Has Gone.mid', 'Jazz-Midi'),
#  ('When Your Lover Has Gone.mid', 'JazzPage'),
#  ('Woody Shaw - Imagination.mid', 'Weimar DB'),
#  ('Wynton Marsalis - April In Paris.mid', 'Weimar DB'),
#  ('Yesterdays.mid', 'Doug McKenzie'),
#  ('Yesterdays.mid', 'Jazz-Midi'),
#  ('You Are Too Beautiful.mid', 'Doug McKenzie'),
#  ('You Are Too Beautiful.mid', 'Jazz-Midi'),
#  ("You Don't Know What Love Is.mid", 'MidKar'),
#  ('You Took Advantage Of Me.mid', 'Oocities'),
#  ("You've Changed.mid", 'MidKar'),
#  ("You've Changed.mid", 'Oocities'),
#  ('Young And Foolish.mid', 'Doug McKenzie'),
#  ('Young And Foolish.mid', 'MidKar'),
#  ('Yours Is My Heart Alone.mid', 'Jazz-Midi'),
#  ('Zoot Sims - All The Things You Are.mid', 'Weimar DB'),
#  ('Zoot Sims - Night And Day (1).mid', 'Weimar DB'),
#  ('Zoot Sims - Night And Day (2).mid', 'Weimar DB')]

# %%
class ScoreParams:
	'''
	Define scores for each parameter
	'''
	def __init__(self,gap,match,mismatch):
		self.gap = gap
		self.match = match
		self.mismatch = mismatch

	def misMatchChar(self,x,y):
		if x != y:
			return self.mismatch
		else:
			return self.match

def getMatrix(sizeX,sizeY,gap):
	'''
	Create an initial matrix of zeros, such that its len(x) x len(y)
	'''
	matrix = []
	for i in range(len(sizeX)+1):
		subMatrix = []
		for j in range(len(sizeY)+1):
			subMatrix.append(0)
		matrix.append(subMatrix)

	# Initializing the first row and first column with the gap values
	for j in range(1,len(sizeY)+1):
		matrix[0][j] = j*gap
	for i in range(1,len(sizeX)+1):
		matrix[i][0] = i*gap
	return matrix

def getTraceBackMatrix(sizeX,sizeY):
	'''
	Create an initial matrix of zeros, such that its len(x) x len(y)
	'''
	matrix = []
	for i in range(len(sizeX)+1):
		subMatrix = []
		for j in range(len(sizeY)+1):
			subMatrix.append('0')
		matrix.append(subMatrix)

	# Initializing the first row and first column with the up or left values
	for j in range(1,len(sizeY)+1):
		matrix[0][j] = 'left'
	for i in range(1,len(sizeX)+1):
		matrix[i][0] = 'up'
	matrix[0][0] = 'done'
	return matrix


def globalAlign(x,y,score):
	'''
	Fill in the matrix with alignment scores
	'''
	matrix = getMatrix(x,y,score.gap)
	traceBack = getTraceBackMatrix(x,y)

	for i in range(1,len(x)+1):
		for j in range(1,len(y)+1):
			left = matrix[i][j-1] + score.gap
			up = matrix[i-1][j] + score.gap
			diag = matrix[i-1][j-1] + score.misMatchChar(x[i-1],y[j-1])
			matrix[i][j] = max(left,up,diag)
			if matrix[i][j] == left:
				traceBack[i][j] = 'left'
			elif matrix[i][j] == up:
				traceBack[i][j] = 'up'
			else:
				traceBack[i][j] = 'diag'
	return matrix,traceBack

def getAlignedSequences(x,y,matrix,traceBack):
	'''
	Obtain x and y globally aligned sequence arrays using the bottom-up approach
	'''
	xSeq = []
	ySeq = []
	i = len(x)
	j = len(y)
	while(i > 0 or j > 0):
		if traceBack[i][j] == 'diag':
			# Diag is scored when x[i-1] == y[j-1]
			xSeq.append(x[i-1])
			ySeq.append(y[j-1])
			i = i-1
			j = j-1
		elif traceBack[i][j] == 'left':
			# Left holds true when '-' is added from x string and y[j-1] from y string
			xSeq.append('-')
			ySeq.append(y[j-1])
			j = j-1
		elif traceBack[i][j] == 'up':
			# Up holds true when '-' is added from y string and x[j-1] from x string
			xSeq.append(x[i-1])
			ySeq.append('-')
			i = i-1
		elif traceBack[i][j] == 'done':
			# Break condition when we reach the [0,0] cell of traceback matrix
			break
	return xSeq,ySeq

def printMatrix(matrix):
	'''
	Create a custom function to print the matrix
	'''
	for i in range(len(matrix)):
		print(matrix[i])
	print()

'''
Driver Code:
'''
x = 'casa'
y = 'aacasa'
print('Input sequences are: ')
print(x)
print(y)
print()
score = ScoreParams(-2,1,-1)
matrix,traceBack = globalAlign(x,y,score)

print('Printing the score matrix:')
printMatrix(matrix)

print('Printing the trace back matrix:')
printMatrix(traceBack)

xSeq,ySeq = getAlignedSequences(x,y,matrix,traceBack)

print('The globally aligned sequences are:')
print(*xSeq[::-1])
print(*ySeq[::-1])
# Out:
# Input sequences are:
# casa
# aacasa
#
# Printing the score matrix:
# [0, -2, -4, -6, -8, -10, -12]
# [-2, -1, -3, -3, -5, -7, -9]
# [-4, -1, 0, -2, -2, -4, -6]
# [-6, -3, -2, -1, -3, -1, -3]
# [-8, -5, -2, -3, 0, -2, 0]
#
# Printing the trace back matrix:
# ['done', 'left', 'left', 'left', 'left', 'left', 'left']
# ['up', 'diag', 'left', 'diag', 'left', 'left', 'left']
# ['up', 'diag', 'diag', 'left', 'diag', 'left', 'left']
# ['up', 'up', 'up', 'diag', 'left', 'diag', 'left']
# ['up', 'up', 'diag', 'up', 'diag', 'left', 'diag']
#
# The globally aligned sequences are:
# - - c a s a
# a a c a s a

# %%
chordino = Chordino(roll_on=1)

path = './data/Complete Examples'

score = ScoreParams(-2, 1, -1)

for orig_filename in orig_files[:1]:
    
    print(orig_filename[0])
    print('-----')
    
    filepath = os.path.join(path, orig_filename[1], orig_filename[0])
    
    score = music21.converter.parse(filepath)
    key = score.analyze('key')
    print(key.tonic.name, key.mode)
    
    orig_conversion_file_path = chordino.preprocess(filepath)
    orig_chords = chordino.extract(orig_conversion_file_path)
    orig_chord_names = [c.chord for c in orig_chords]
    
    print(orig_conversion_file_path)
    print("-".join(orig_chord_names))
    print('---------------')
    
    chord_extractor.clear_conversion_cache()
        
    improv_filenames = [os.path.join(path, g[1], g[0]) for g in impro_files if g[0] == f[0]]
    
    for impro_filepath in improv_filenames:
        
        score = music21.converter.parse(impro_filepath)
        key = score.analyze('key')
        print(key.tonic.name, key.mode)
        
        print(impro_filepath)
        print('-----')
        
        impro_conversion_file_path = chordino.preprocess(impro_filepath)
        impro_chords = chordino.extract(impro_conversion_file_path)
        impro_chord_names = [c.chord for c in impro_chords]
        
        print(impro_conversion_file_path)
        print("-".join(impro_chord_names))
        print('---------------')
    
        matrix, traceBack = globalAlign(orig_chord_names, impro_chord_names, score)

        xSeq, ySeq = getAlignedSequences(orig_chord_names, impro_chord_names, matrix, traceBack)

        print('The globally aligned sequences are:')
        print(*xSeq[::-1])
        print('-----')
        print(*ySeq[::-1])
        print('--------------------------------')
        
        chord_extractor.clear_conversion_cache()
# Out:
# A Felicidade.mid
# -----
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/music21/midi/translate.py:785: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=2, channel=None, data=b'Bater\xeda'>; getting generic Instrument
#   warnings.warn(
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/music21/midi/translate.py:790: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent PROGRAM_CHANGE, track=2, channel=10, data=0>; getting generic UnpitchedPercussion
#   warnings.warn(
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/music21/midi/translate.py:785: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=6, channel=None, data=b'Melod\xeda'>; getting generic Instrument
#   warnings.warn(
# E- major
# /tmp/extractor/A Felicidade
# N-D-Cm7-Gm7-D7-Gm7-Ebmaj7-Fm7-Dm7b5-Cm7-Fm7b5-C#-A7-Abmaj7-G-Cm7-Dm7b5-G7-Cm7-Dm7b5-Eb6-Bbm7-Eb7-Fm7-Bb7-Eb6-Am7b5-Daug-Am7b5-Daug-Gm7b5-C7-Fm7b5-Eb6-Dm7b5-G7-Cm7-Dm7b5-G7-Cm7-Gm7-D7-Gm7-Gm-Eb6-C7-Fm7-Dm7b5-Cm7-B7-C#-Eb7-Abmaj7-G7-Cm7-Gm7-Cm7-Dm7b5-Cm7-Dm7b5-Cm7-Dm7b5-Cm7-Gm7-D7-Gm7-Gm-Eb6-C7-Fm7-Dm7b5-Cm7-F7-Bbm7-A7-Abmaj7-G7-Cm7-Dm7b5-G7-Cm7-Dm7b5-Cm7-Ab7-Bb6-Bbm7-Eb7-Fm7-Bb7-Eb6-Am7b5-Cm7b5/Bb-Gm7b5-C7-Fm7b5-Eb6-Dm7b5-G7-Cm7-Dm7b5-Cm7-Gm7-D7-Gm7-Ebmaj7-C7-Fm-Cm7-Bm7b5-Bbm7-A7-Cm-G7-Cm7-Dm7b5-G7-Cm7-Dm7b5-Cm7-Dm7b5-Cm7-Dm7b5-Cm7-N
# ---------------
# A minor
# ./data/Complete Examples/JazzPage/A Felicidade.mid
# -----
# /tmp/extractor/A Felicidade
# N-Am-Em-B7-Em-C-Bm7b5-Dm7b5-Am7-Abm7-Gm7-C7-F-E7-Am-D7-Am7-Bm7b5-Am-Dm-G7-Cmaj7-Gm7-C7-F6-G7-Ebaug-C6-B7-Em7-G7-C-Am7-Dm7-Am7-Bm7b5-Am-Em-B7-Em-Dm7-Fm7b5-C-Bm7b5-E7-Am7-Abm7-Gm7-C7-F-E7-Am-D7-Am7-Bm7b5-E7-Am-Dm-G7-G6-Gm7-Bbm7b5-F-G7-Gaug-C6-F#m7-Baug-Em7-Bbm6-Dm7-C-Am7-Dm7-E7-Am7-Bm7b5-Am-Em-B7-Em-Dm7-Fm7b5-C-Bm7b5-E7-Am7-Abm7-Gm7-C7-F-E7-Am-D7-Am7-Bm7b5-Am-Dm-G7-Cmaj7-Gm7-C7-F6-G7-Fm7b5/Eb-C6-Em7-Gm7b5-Dm7-Cmaj7-Am7-Dm7-Am-N
# ---------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_113430/1300442528.py in <module>
#      45         print('---------------')
#      46
# ---> 47         matrix, traceBack = globalAlign(orig_chord_names, impro_chord_names, score)
#      48
#      49         xSeq, ySeq = getAlignedSequences(orig_chord_names, impro_chord_names, matrix, traceBack)
#
# /tmp/ipykernel_113430/742190419.py in globalAlign(x, y, score)
#      56         Fill in the matrix with alignment scores
#      57 	'''
# ---> 58         matrix = getMatrix(x,y,score.gap)
#      59         traceBack = getTraceBackMatrix(x,y)
#      60
#
# AttributeError: 'Score' object has no attribute 'gap'

# %%
import pychord

# %%
c = pychord.ChordProgression(['C', 'Am', 'F', 'G'])

# %%
c.transpose(1)

# %%
c
# Out:
# <ChordProgression: Db | Bbm | Gb | Ab>
