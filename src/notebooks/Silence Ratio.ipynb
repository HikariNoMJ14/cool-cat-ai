# %%
import pandas as pd

import sys
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams


sys.path.append('../..')

# from src.evaluation.evaluation import prepare_timestep_melody

# %%
file = '/media/manu/Data/PycharmProjects/thesis/mlruns/10/d7440c51ae474828b64d3e11c741c8e1/artifacts/evaluation_seen.csv'
df = pd.read_csv(file, index_col=0)

# %%
rcParams['figure.figsize'] = 5,5
ax = sns.distplot(df['SR'])
# ax.set(xticks=np.arange(0,900,50))
ax.set(xlabel='silence ratio (SR)', ylabel='density')
# plt.axvline(x=df['SR'].mean(), color='blue')
# plt.axvline(x=df['SR'].mean()-df['SR'].std(), color='green')
# plt.axvline(x=df['SR'].mean()+df['SR'].std(), color='green')
# Out:
# /home/manu/anaconda3/envs/thesis/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'silence ratio (SR)'), Text(0, 0.5, 'density')]

# %%
file2 = '/media/manu/Data/PycharmProjects/thesis/mlruns/5/86bb55472c2f4797b00e486efe09fe15/artifacts/evaluation_seen.csv'
df2 = pd.read_csv(file2, index_col=0)

# %%
rcParams['figure.figsize'] = 5,5
ax = sns.distplot(df2['SR'])
# ax.set(xticks=np.arange(0,900,50))
ax.set(xlabel='silence ratio (SR)', ylabel='density')
# plt.axvline(x=df2['SR'].mean(), color='blue')
# plt.axvline(x=df['SR'].mean()-df['SR'].std(), color='green')
# plt.axvline(x=df['SR'].mean()+df['SR'].std(), color='green')
# Out:
# /home/manu/anaconda3/envs/thesis/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'silence ratio (SR)'), Text(0, 0.5, 'density')]
