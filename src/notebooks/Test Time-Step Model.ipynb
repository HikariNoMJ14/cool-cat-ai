# %%
import torch
import os
import sys

sys.path.append('../..')

# %%
model_path = os.path.join(
    '/media/manu/Data/PycharmProjects/thesis/mlruns/6/' +
    '59716f59ea91408d9c56b6b39004b160/artifacts/22_06_17_17_18_49_transpose_none_chord_extended_7_batchsize_128_seed_1234567890_best_val.pt'
)

model = torch.load(open(model_path, 'rb'))

# %%
model.metadata_encoder[0]
# Out:
# Embedding(120, 256, scale_grad_by_freq=True)

# %%
 model.metadata_encoder[0](torch.Tensor([-1]).long().cuda()).cpu().detach().numpy().squeeze()
# Out:
# /opt/conda/conda-bld/pytorch_1646755897462/work/aten/src/ATen/native/cuda/Indexing.cu:650: indexSelectSmallIndex: block: [1,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /opt/conda/conda-bld/pytorch_1646755897462/work/aten/src/ATen/native/cuda/Indexing.cu:650: indexSelectSmallIndex: block: [1,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /opt/conda/conda-bld/pytorch_1646755897462/work/aten/src/ATen/native/cuda/Indexing.cu:650: indexSelectSmallIndex: block: [1,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /opt/conda/conda-bld/pytorch_1646755897462/work/aten/src/ATen/native/cuda/Indexing.cu:650: indexSelectSmallIndex: block: [1,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /opt/conda/conda-bld/pytorch_1646755897462/work/aten/src/ATen/native/cuda/Indexing.cu:650: indexSelectSmallIndex: block: [1,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
