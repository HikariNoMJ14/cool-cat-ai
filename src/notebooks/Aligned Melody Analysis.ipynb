# %%
import json
import seaborn as sns

# %%
errors = json.load(open('../data/alignment_scores/errors-08-02-2022-21-51-37.json'))
scores = json.load(open('../data/alignment_scores/song_scores-08-02-2022-21-51-37.json'))
no_chords = json.load(open('../data/alignment_scores/no_chords-08-02-2022-21-51-37.json'))

# %%
errors
# Out:
# {'Real Book/In Your Own Sweet Way.mid': ['Chord progression time signature different from melody time signature ']}

# %%
no_chords
# Out:
# ['Real Book/Give My Regards To Broadway.mid',
#  'Real Book/Happy Birthday.mid',
#  'Real Book/Side By Side.mid',
#  "Real Book/C'est Magnifique.mid",
#  'Real Book/Take Me Out To The Ball Game.mid',
#  'Real Book/More.mid',
#  'Real Book/Once Upon A Summertime.mid',
#  'Real Book/Palladium.mid',
#  'Real Book/When Your Lover Has Gone.mid',
#  'Real Book/Yours Is My Heart Alone.mid']

# %%
for k,v in scores.items(): 
    c_p_key = v['chord_progression_key']
    key = [v['melody_key'][0].replace('-', 'b'), v['melody_key'][1]]
               
    if key != c_p_key:
        print('DIFF', key, c_p_key)
#     else:
#         print('SAME', key, c_p_key)
# Out:
# DIFF ['C', 'minor'] ['A', 'minor']
# DIFF ['F', 'major'] ['D', 'minor']
# DIFF ['A', 'minor'] ['F', 'major']
# DIFF ['G', 'minor'] ['Bb', 'major']
# DIFF ['C', 'minor'] ['C', 'major']
# DIFF ['Bb', 'major'] ['F', 'minor']
# DIFF ['A', 'minor'] ['C', 'major']
# DIFF ['C', 'major'] ['A', 'minor']
# DIFF ['F', 'minor'] ['Ab', 'major']
# DIFF ['G', 'minor'] ['Bb', 'major']
# DIFF ['A', 'minor'] ['C', 'major']
# DIFF ['Bb', 'minor'] ['Db', 'major']
# DIFF ['E', 'minor'] ['G', 'minor']
# DIFF ['F', 'minor'] ['F', 'major']
# DIFF ['F', 'major'] ['Ab', 'major']
# DIFF ['F', 'major'] ['C', 'major']
# DIFF ['C', 'minor'] ['Eb', 'major']
# DIFF ['A', 'minor'] ['C', 'major']
# DIFF ['E', 'minor'] ['G', 'major']
# DIFF ['D', 'minor'] ['C', 'major']
# DIFF ['G', 'major'] ['C', 'major']
# DIFF ['G', 'minor'] ['G', 'major']
# DIFF ['Ab', 'major'] ['Eb', 'major']
# DIFF ['F', 'minor'] ['Ab', 'major']
# DIFF ['D', 'minor'] ['F', 'major']
# DIFF ['Eb', 'major'] ['F', 'major']
# ...

# %%
sns.distplot([s['starting_measure'] for s in scores.values() if s['starting_measure'] is not None and s['starting_measure']])
# Out:
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
[(k.split('/')[-1], s['starting_measure']) 
 for k, s in scores.items() 
 if s['starting_measure'] is not None and s['starting_measure'] > 2]
# Out:
# [('A Felicidade.mid', 75),
#  ('A Night In Tunisia.mid', 34),
#  ('Airegin.mid', 28),
#  ('Anthropology.mid', 6),
#  ("Bags' Groove.mid", 16),
#  ('Beautiful Friendship.mid', 4),
#  ('Bemsha Swing.mid', 3),
#  ("Let's Cool One.mid", 3),
#  ("Lulu's Back In Town.mid", 26),
#  ('Maiden Voyage.mid', 4),
#  ('Make Someone Happy.mid', 4),
#  ('Margie.mid', 18),
#  ('Doxy.mid', 3),
#  ('Eighty-One.mid', 4),
#  ('Embraceable You.mid', 32),
#  ('Esp.mid', 7),
#  ('Falling Grace.mid', 11),
#  ('Fools Rush In.mid', 11),
#  ('Giant Steps.mid', 10),
#  ("Groovin' High.mid", 10),
#  ("Peri's Scope.mid", 4),
#  ('Reflections.mid', 3),
#  ('Round Midnight.mid', 10),
#  ('Secret Love.mid', 42),
#  ('Shiny Stockings.mid', 22),
#  ('Speak Low.mid', 3),
#  ('Blue Monk.mid', 14),
#  ('Blue Train.mid', 4),
#  ('Blues For Alice.mid', 3),
#  ('But Beautiful.mid', 10),
#  ('Cottontail.mid', 4),
#  ('Criss-Cross.mid', 3),
#  ('Daahoud.mid', 16),
#  ('Dearly Beloved.mid', 33),
#  ('Deep Purple.mid', 10),
# ...

# %%
wrong_songs = [
    "A Felicidade",
    "A Night In Tunisia",
    "All Or Nothing At All",
    "Accentuate The Positive",
    "Just The Way You Look Tonight",
    "Lady Is A Tramp",
    "Lazybird",
    "Make Someone Happy",
    "Falling Grace",
    "Recado Bossa Nova",
    "Speak Low",
    "Blue Train",
    "Daahoud",
    "Dancing On The Ceiling",
    "Black Orpheus",
    "I Don't Know Why",
    "I Got Rhythm",
    "I'll Be Seeing You",
    "In Your Own Sweet Way",
    "Isn't It Romantic",
    "New York, New York",
    "Oleo"
]

# %%
[(k.split('/')[-1], s['starting_measure']) 
 for k, s in scores.items() 
 if k.split('/')[-1].replace('.mid', '') in wrong_songs]
# Out:
# [('A Felicidade.mid', 75),
#  ('A Night In Tunisia.mid', 34),
#  ('Accentuate The Positive.mid', 2),
#  ('All Or Nothing At All.mid', 2),
#  ('Just The Way You Look Tonight.mid', 2),
#  ('Lady Is A Tramp.mid', 2),
#  ('Lazybird.mid', 2),
#  ('Make Someone Happy.mid', 4),
#  ('Falling Grace.mid', 11),
#  ('Recado Bossa Nova.mid', 2),
#  ('Speak Low.mid', 3),
#  ('Blue Train.mid', 4),
#  ('Daahoud.mid', 16),
#  ('Dancing On The Ceiling.mid', 2),
#  ('Black Orpheus.mid', 2),
#  ("I Don't Know Why.mid", 3),
#  ('I Got Rhythm.mid', 3),
#  ("I'll Be Seeing You.mid", 2),
#  ('In Your Own Sweet Way.mid', None),
#  ("Isn't It Romantic.mid", 2),
#  ('New York, New York.mid', 2),
#  ('Oleo.mid', 8)]

# %%
49 179 3 32 A Felicidade
34 106 3 4  A Foggy Day
80 111 1 31 A Night In Tunisia
32 122 3 26 Accentuate The Positive
40 125 3 5  After You've Gone
32 100 3 4  Ain't Misbehavin'
36 112 3 4  Airegin
32 101 3 5  All Of Me
