# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
no_t = pd.read_csv('/home/manu/Downloads/results.csv', index_col=0)

# %%
all_t = pd.read_csv('/home/manu/Downloads/results (1).csv', index_col=0)

# %%
no_t
# Out:
#     epoch  train_loss  train_ppl  valid_loss  valid_ppl  train_pitch_loss  \
# 0       1    0.439741   1.552305    0.120859   1.128466          0.711656
# 1       2    0.179715   1.196876    0.090728   1.094971          0.258093
# 2       3    0.144688   1.155679    0.079764   1.083031          0.199823
# 3       4    0.125161   1.133331    0.072078   1.074740          0.168737
# 4       5    0.115279   1.122187    0.081987   1.085442          0.154168
# 5       6    0.109146   1.115325    0.070436   1.072976          0.144217
# 6       7    0.102633   1.108085    0.062883   1.064902          0.133616
# 7       8    0.095507   1.100216    0.065200   1.067372          0.124979
# 8       9    0.092037   1.096406    0.064466   1.066589          0.118684
# 9      10    0.087326   1.091252    0.065881   1.068100          0.111641
# 10     11    0.084432   1.088099    0.058903   1.060672          0.107766
# 11     12    0.080410   1.083731    0.052674   1.054086          0.103264
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(no_t['valid_pitch_loss'], label='no')
ax.plot(all_t['valid_pitch_loss'], label='all')
fig.legend(loc="upper right")
