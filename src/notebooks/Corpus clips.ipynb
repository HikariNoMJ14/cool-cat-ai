# %%
import os
import re
import sys

import numpy as np
import pandas as pd
from glob import glob

sys.path.append('../..')

from src.melody import DurationMelody, TimeStepMelody
from src.utils import get_chord_progressions

# %%
folder = os.path.join('..', '..', 'data', 'encoded', 'duration', 'mono')

files = [y for x in os.walk(folder) for y in glob(os.path.join(x[0], '*.csv'))]

# %%
files
# Out:
# ['../../data/encoded/duration/mono/Jazz-Midi/Polka Dots And Moonbeams -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/April In Paris -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Autumn Leaves (1) -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/But Beautiful -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Dancing On The Ceiling -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/East Of The Sun -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Eighty-One -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Eighty-One -2-.csv',
#  "../../data/encoded/duration/mono/Jazz-Midi/I Can't Give You Anything But Love -1-.csv",
#  '../../data/encoded/duration/mono/Jazz-Midi/I Concentrate On You -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/I Should Care -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/My Funny Valentine -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Night And Day -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Our Love Is Here To Stay -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/People -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -2-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -3-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -4-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -5-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -6-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Secret Love -7-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/September Song -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Since I Fell For You -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Since I Fell For You -2-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Strangers In The Night -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Sweet Georgia Brown -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/The Way You Look Tonight (1) -1-.csv',
#  "../../data/encoded/duration/mono/Jazz-Midi/They Can't Take That Away From Me (1) -1-.csv",
#  "../../data/encoded/duration/mono/Jazz-Midi/They Can't Take That Away From Me (1) -2-.csv",
#  '../../data/encoded/duration/mono/Jazz-Midi/Yesterdays -1-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/Yesterdays -2-.csv',
#  '../../data/encoded/duration/mono/Jazz-Midi/You Are Too Beautiful -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Art Pepper - Anthropology -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Art Pepper - Anthropology -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Art Pepper - Anthropology -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Art Pepper - Anthropology -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Ben Webster - Bye Bye Blackbird -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Ben Webster - Bye Bye Blackbird -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Ben Webster - Bye Bye Blackbird -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Ben Webster - Night And Day -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Ben Webster - Night And Day -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Benny Carter - Just Friends -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Benny Carter - Just Friends -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Benny Carter - Just Friends -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Benny Carter - Long Ago And Far Away (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Bix Beiderbecke - Margie -1-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Bob Berg - I Didn't Know What Time It Was -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Bob Berg - I Didn't Know What Time It Was -2-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Bob Berg - I Didn't Know What Time It Was -3-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Branford Marsalis - The Nearness Of You -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Branford Marsalis - The Nearness Of You -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Cannonball Adderley - So What -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Cannonball Adderley - So What -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Cannonball Adderley - Star Eyes -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Cannonball Adderley - Star Eyes -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Blues For Alice -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Blues For Alice -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -29-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -30-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -31-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -7-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -8-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -9-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -10-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -11-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -13-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -7-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -8-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -9-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Oleo -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Oleo -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Oleo -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -17-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -18-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -19-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -20-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -21-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -22-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -23-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -24-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -25-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -26-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -27-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - So What -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - So What -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Konitz - All The Things You Are -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Konitz - All The Things You Are -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Konitz - All The Things You Are -3-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Lee Konitz - I'll Remember April -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Lee Konitz - I'll Remember April -2-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Lee Konitz - I'll Remember April -3-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Lee Konitz - Mean To Me -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Konitz - Mean To Me -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Morgan - Blue Train -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Morgan - Blue Train -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Morgan - Blue Train -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Benny Carter - Long Ago And Far Away (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Blues For Alice -3-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Clifford Brown - I'll Remember April (2) -1-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -3-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Dizzy Gillespie - Groovin' High -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - Yesterdays -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -7-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -16-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -28-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (2) -12-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Oleo -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Morgan - Blue Train -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -2-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bags' Groove -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Red Garland - Oleo -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Stan Getz - My Funny Valentine -3-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Don't Blame Me -1-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Donna Lee -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Donna Lee -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - My Little Suede Shoes -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Ornithology -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Parker - Star Eyes -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Charlie Shavers - Limehouse Blues -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chet Baker - Just Friends -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chet Baker - Just Friends -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chet Baker - Long Ago And Far Away -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chet Baker - There Will Never Be Another You (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chet Baker - There Will Never Be Another You (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chris Potter - Anthropology -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chris Potter - Anthropology -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chris Potter - Anthropology -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chris Potter - Anthropology -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Chris Potter - In A Sentimental Mood -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - A Night In Tunisia -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - A Night In Tunisia -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - Daahoud -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - Daahoud -2-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Clifford Brown - I'll Remember April (1) -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Clifford Brown - I'll Remember April (1) -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -7-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - There Will Never Be Another You -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - There Will Never Be Another You -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - There Will Never Be Another You -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Murray - Ask Me Now -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Dickie Wells - I Got Rhythm -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Dickie Wells - I Got Rhythm -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Dizzy Gillespie - Anthropology -1-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Dizzy Gillespie - Groovin' High -1-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Don Ellis - I Love You -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Don Ellis - I Love You -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Fats Navarro - Good Bait (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Fats Navarro - Good Bait (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Freddie Hubbard - Maiden Voyage -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Freddie Hubbard - Maiden Voyage -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Freddie Hubbard - Speak No Evil -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/George Coleman - Maiden Voyage -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - My Funny Valentine -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - My Funny Valentine -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - Yesterdays -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - Yesterdays -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/J J Johnson - Yesterdays -4-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/John Coltrane - Bessie's Blues -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/John Coltrane - Bessie's Blues -2-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/John Coltrane - Bessie's Blues -3-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/John Coltrane - Bessie's Blues -4-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/John Coltrane - Bessie's Blues -5-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Blue Train -8-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -10-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -11-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -7-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -8-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (1) -9-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Giant Steps (2) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -10-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -11-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -12-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -13-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -14-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/John Coltrane - Impressions (1) -15-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lee Morgan - Blue Train -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Lionel Hampton - Memories Of You -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Louis Armstrong - Once In A While -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Airegin -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Airegin -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Airegin -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Eighty-One -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Esp -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Oleo (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Oleo (1) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Oleo (2) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - Oleo (2) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - So What -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Miles Davis - So What -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - All The Things You Are -1-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bags' Groove -1-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bemsha Swing -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bemsha Swing -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bemsha Swing -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bemsha Swing -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Bemsha Swing -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Softly As In A Morning Sunrise -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Softly As In A Morning Sunrise -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Milt Jackson - Softly As In A Morning Sunrise -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -4-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Clifford Brown - I'll Remember April (2) -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - Jordu -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Clifford Brown - Jordu -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Coleman Hawkins - Sophisticated Lady -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Curtis Fuller - Blue Train -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Curtis Fuller - Blue Train -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Curtis Fuller - Blue Train -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Curtis Fuller - Blue Train -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Curtis Fuller - Blue Train -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/David Liebman - Softly As In A Morning Sunrise -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pat Metheny - All The Things You Are -6-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Paul Desmond - Alone Together -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Paul Desmond - Alone Together -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Paul Desmond - Alone Together -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pepper Adams - A Night In Tunisia -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Pepper Adams - How High The Moon -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - Cottontail -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - Honeysuckle Rose -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - On A Slow Boat To China -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - On A Slow Boat To China -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - On A Slow Boat To China -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Phil Woods - On A Slow Boat To China -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Red Garland - Oleo -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sidney Bechet - Limehouse Blues -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sidney Bechet - Summertime -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sidney Bechet - Summertime -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sidney Bechet - Summertime -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sidney Bechet - Summertime -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sonny Rollins - Airegin -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sonny Rollins - Airegin -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Sonny Rollins - Airegin -3-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Sonny Rollins - I'll Remember April -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Sonny Rollins - I'll Remember April -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Stan Getz - My Funny Valentine -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Stan Getz - My Funny Valentine -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Steve Lacy - Alone Together -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Steve Lacy - Ask Me Now -1-.csv',
#  "../../data/encoded/duration/mono/Weimar DB/Steve Lacy - Let's Cool One -1-.csv",
#  "../../data/encoded/duration/mono/Weimar DB/Steve Lacy - Let's Cool One -2-.csv",
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Dolores -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Dolores -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Eighty-One -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Eighty-One -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Eighty-One -3-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Eighty-One -4-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Eighty-One -5-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Esp -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Esp -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Speak No Evil -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wayne Shorter - Speak No Evil -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Woody Shaw - Imagination -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wynton Marsalis - April In Paris -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Wynton Marsalis - April In Paris -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Zoot Sims - All The Things You Are -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Zoot Sims - Night And Day (1) -1-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Zoot Sims - Night And Day (1) -2-.csv',
#  '../../data/encoded/duration/mono/Weimar DB/Zoot Sims - Night And Day (2) -1-.csv']

# %%
chord_progressions = get_chord_progressions('../..')

metadata = pd.read_csv('../../data/finalised/metadata_v2.csv', index_col=0)

n_measures = 8

for file in files:
    dur_melody = DurationMelody(file)
    
    try:
        tempo = metadata[
            (metadata['filename'] == re.sub(' -[0-9,o]*-', '', dur_melody.filename)) &
            (metadata['source'] == dur_melody.source)          
        ]['tempo'].values[0]
        
        
        if tempo <= 90:
            tempo = 90
        elif tempo > 150:
            tempo = 150
        else:
            tempo = 120
    except:
        continue
    
    dur_melody.set_song_structure(chord_progressions[dur_melody.song_name])
     
    df = pd.read_csv(file, index_col=0)
    df = df.rename({
        'pitch': 'improvised_pitch',
        'duration': 'improvised_duration',
    }, axis=1)
    df['measure'] = (df['ticks'] // 48).astype('int')
    
    start_measure = int(np.floor(np.random.random() * (df['measure'].max() - n_measures)/4)) * 4
    
    df = df[df['type'] == 'improvised']
    df = df[(df['measure'] >= start_measure) & (df['measure'] < start_measure+n_measures)]
        
    dur_melody.encoded = df
    dur_melody.to_midi('../../data/generated/subjective_evaluation/' + 
                       dur_melody.source + ' - ' +
                       dur_melody.filename.replace('.csv', '') + 
                       f' [{start_measure},{start_measure+n_measures}].mid',
                      tempo)
    
    
    print(tempo)
    print( dur_melody.source + ' - ' +
                       dur_melody.filename.replace('.csv', '') + 
                       f' [{start_measure},{start_measure+n_measures}].mid')
# Out:
# 150
# Jazz-Midi - Polka Dots And Moonbeams -1- [12,20].mid
# 120
# Jazz-Midi - April In Paris -1- [12,20].mid
# 90
# Jazz-Midi - Autumn Leaves (1) -1- [16,24].mid
# 150
# Jazz-Midi - But Beautiful -1- [16,24].mid
# 120
# Jazz-Midi - Dancing On The Ceiling -1- [8,16].mid
# 120
# Jazz-Midi - East Of The Sun -1- [0,8].mid
# 120
# Jazz-Midi - Eighty-One -1- [4,12].mid
# 120
# Jazz-Midi - Eighty-One -2- [8,16].mid
# 90
# Jazz-Midi - I Can't Give You Anything But Love -1- [20,28].mid
# 120
# Jazz-Midi - I Concentrate On You -1- [0,8].mid
# 120
# Jazz-Midi - I Should Care -1- [4,12].mid
# 120
# Jazz-Midi - My Funny Valentine -1- [12,20].mid
# 90
# Jazz-Midi - Night And Day -1- [36,44].mid
# 120
# Jazz-Midi - Our Love Is Here To Stay -1- [4,12].mid
# 120
# Jazz-Midi - People -1- [12,20].mid
# 90
# Jazz-Midi - Secret Love -1- [12,20].mid
# 90
# Jazz-Midi - Secret Love -2- [8,16].mid
# 90
# Jazz-Midi - Secret Love -3- [12,20].mid
# 90
# Jazz-Midi - Secret Love -4- [8,16].mid
# 90
# Jazz-Midi - Secret Love -5- [8,16].mid
# 90
# Jazz-Midi - Secret Love -6- [0,8].mid
# 90
# Jazz-Midi - Secret Love -7- [0,8].mid
# 120
# Jazz-Midi - September Song -1- [16,24].mid
# 150
# Jazz-Midi - Since I Fell For You -1- [4,12].mid
# 150
# Jazz-Midi - Since I Fell For You -2- [0,8].mid
# 120
# Jazz-Midi - Strangers In The Night -1- [0,8].mid
# 90
# Jazz-Midi - Sweet Georgia Brown -1- [0,8].mid
# 120
# Jazz-Midi - The Way You Look Tonight (1) -1- [36,44].mid
# 120
# Jazz-Midi - They Can't Take That Away From Me (1) -1- [24,32].mid
# 120
# Jazz-Midi - They Can't Take That Away From Me (1) -2- [24,32].mid
# 120
# Jazz-Midi - Yesterdays -1- [4,12].mid
# 120
# Jazz-Midi - Yesterdays -2- [0,8].mid
# 120
# Jazz-Midi - You Are Too Beautiful -1- [4,12].mid
# 150
# Weimar DB - Art Pepper - Anthropology -1- [20,28].mid
# 150
# Weimar DB - Art Pepper - Anthropology -2- [12,20].mid
# 150
# Weimar DB - Art Pepper - Anthropology -3- [0,8].mid
# 150
# Weimar DB - Art Pepper - Anthropology -4- [4,12].mid
# 120
# Weimar DB - Ben Webster - Bye Bye Blackbird -1- [8,16].mid
# 120
# Weimar DB - Ben Webster - Bye Bye Blackbird -2- [0,8].mid
# 120
# Weimar DB - Ben Webster - Bye Bye Blackbird -3- [8,16].mid
# 150
# Weimar DB - Ben Webster - Night And Day -1- [0,8].mid
# 150
# Weimar DB - Ben Webster - Night And Day -2- [28,36].mid
# 150
# Weimar DB - Benny Carter - Just Friends -1- [16,24].mid
# 150
# Weimar DB - Benny Carter - Just Friends -2- [20,28].mid
# 150
# Weimar DB - Benny Carter - Just Friends -3- [4,12].mid
# 150
# Weimar DB - Benny Carter - Long Ago And Far Away (1) -1- [4,12].mid
# 150
# Weimar DB - Bix Beiderbecke - Margie -1- [12,20].mid
# 120
# Weimar DB - Bob Berg - I Didn't Know What Time It Was -1- [16,24].mid
# 120
# Weimar DB - Bob Berg - I Didn't Know What Time It Was -2- [0,8].mid
# 120
# Weimar DB - Bob Berg - I Didn't Know What Time It Was -3- [0,8].mid
# 90
# Weimar DB - Branford Marsalis - The Nearness Of You -1- [20,28].mid
# 90
# Weimar DB - Branford Marsalis - The Nearness Of You -2- [8,16].mid
# 120
# Weimar DB - Cannonball Adderley - So What -1- [16,24].mid
# 120
# Weimar DB - Cannonball Adderley - So What -2- [4,12].mid
# 150
# Weimar DB - Cannonball Adderley - Star Eyes -1- [4,12].mid
# 150
# Weimar DB - Cannonball Adderley - Star Eyes -2- [16,24].mid
# 150
# Weimar DB - Charlie Parker - Blues For Alice -1- [0,8].mid
# 150
# Weimar DB - Charlie Parker - Blues For Alice -2- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -29- [12,20].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -3- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -30- [16,24].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -31- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -4- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -5- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -6- [8,16].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -7- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -8- [12,20].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -9- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -1- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -10- [8,16].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -11- [16,24].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -13- [12,20].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -2- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -3- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -4- [16,24].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -5- [8,16].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -6- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -7- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -8- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -9- [20,28].mid
# 150
# Weimar DB - John Coltrane - Oleo -1- [16,24].mid
# 150
# Weimar DB - John Coltrane - Oleo -2- [8,16].mid
# 150
# Weimar DB - John Coltrane - Oleo -3- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -17- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -18- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -19- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -2- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -20- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -21- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -22- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -23- [12,20].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -24- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -25- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -26- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -27- [0,8].mid
# 120
# Weimar DB - John Coltrane - So What -1- [20,28].mid
# 120
# Weimar DB - John Coltrane - So What -2- [16,24].mid
# 150
# Weimar DB - Lee Konitz - All The Things You Are -1- [16,24].mid
# 150
# Weimar DB - Lee Konitz - All The Things You Are -2- [12,20].mid
# 150
# Weimar DB - Lee Konitz - All The Things You Are -3- [12,20].mid
# 150
# Weimar DB - Lee Konitz - I'll Remember April -1- [32,40].mid
# 150
# Weimar DB - Lee Konitz - I'll Remember April -2- [4,12].mid
# 150
# Weimar DB - Lee Konitz - I'll Remember April -3- [32,40].mid
# 120
# Weimar DB - Lee Konitz - Mean To Me -1- [12,20].mid
# 120
# Weimar DB - Lee Konitz - Mean To Me -2- [0,8].mid
# 120
# Weimar DB - Lee Morgan - Blue Train -1- [0,8].mid
# 120
# Weimar DB - Lee Morgan - Blue Train -2- [0,8].mid
# 120
# Weimar DB - Lee Morgan - Blue Train -3- [0,8].mid
# 150
# Weimar DB - Benny Carter - Long Ago And Far Away (2) -1- [8,16].mid
# 150
# Weimar DB - Charlie Parker - Blues For Alice -3- [0,8].mid
# 150
# Weimar DB - Clifford Brown - I'll Remember April (2) -1- [20,28].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -3- [12,20].mid
# 150
# Weimar DB - Dizzy Gillespie - Groovin' High -2- [8,16].mid
# 120
# Weimar DB - J J Johnson - Yesterdays -3- [4,12].mid
# 120
# Weimar DB - John Coltrane - Blue Train -7- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -16- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -28- [4,12].mid
# 150
# Weimar DB - John Coltrane - Impressions (2) -12- [0,8].mid
# 150
# Weimar DB - John Coltrane - Oleo -4- [4,12].mid
# 120
# Weimar DB - Lee Morgan - Blue Train -4- [0,8].mid
# 150
# Weimar DB - Miles Davis - Esp -2- [16,24].mid
# 150
# Weimar DB - Milt Jackson - Bags' Groove -2- [0,8].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -5- [0,8].mid
# 150
# Weimar DB - Red Garland - Oleo -1- [20,28].mid
# 120
# Weimar DB - Stan Getz - My Funny Valentine -3- [12,20].mid
# 90
# Weimar DB - Charlie Parker - Don't Blame Me -1- [20,28].mid
# 150
# Weimar DB - Charlie Parker - Donna Lee -1- [12,20].mid
# 150
# Weimar DB - Charlie Parker - Donna Lee -2- [8,16].mid
# 120
# Weimar DB - Charlie Parker - My Little Suede Shoes -1- [12,20].mid
# 150
# Weimar DB - Charlie Parker - Ornithology -1- [8,16].mid
# 120
# Weimar DB - Charlie Parker - Star Eyes -1- [8,16].mid
# 150
# Weimar DB - Charlie Shavers - Limehouse Blues -1- [4,12].mid
# 150
# Weimar DB - Chet Baker - Just Friends -1- [0,8].mid
# 150
# Weimar DB - Chet Baker - Just Friends -2- [0,8].mid
# 150
# Weimar DB - Chet Baker - Long Ago And Far Away -1- [12,20].mid
# 150
# Weimar DB - Chet Baker - There Will Never Be Another You (1) -1- [0,8].mid
# 150
# Weimar DB - Chet Baker - There Will Never Be Another You (2) -1- [16,24].mid
# 150
# Weimar DB - Chris Potter - Anthropology -1- [12,20].mid
# 150
# Weimar DB - Chris Potter - Anthropology -2- [16,24].mid
# 150
# Weimar DB - Chris Potter - Anthropology -3- [12,20].mid
# 150
# Weimar DB - Chris Potter - Anthropology -4- [4,12].mid
# 150
# Weimar DB - Clifford Brown - A Night In Tunisia -1- [40,48].mid
# 150
# Weimar DB - Clifford Brown - A Night In Tunisia -2- [32,40].mid
# 150
# Weimar DB - Clifford Brown - Daahoud -1- [0,8].mid
# 150
# Weimar DB - Clifford Brown - Daahoud -2- [8,16].mid
# 150
# Weimar DB - Clifford Brown - I'll Remember April (1) -1- [12,20].mid
# 150
# Weimar DB - Clifford Brown - I'll Remember April (1) -2- [0,8].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -4- [8,16].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -5- [12,20].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -6- [0,8].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -7- [4,12].mid
# 150
# Weimar DB - David Liebman - There Will Never Be Another You -1- [8,16].mid
# 150
# Weimar DB - David Liebman - There Will Never Be Another You -2- [8,16].mid
# 150
# Weimar DB - David Liebman - There Will Never Be Another You -3- [16,24].mid
# 120
# Weimar DB - David Murray - Ask Me Now -1- [8,16].mid
# 150
# Weimar DB - Dickie Wells - I Got Rhythm -1- [20,28].mid
# 150
# Weimar DB - Dickie Wells - I Got Rhythm -2- [0,8].mid
# 150
# Weimar DB - Dizzy Gillespie - Anthropology -1- [0,8].mid
# 150
# Weimar DB - Dizzy Gillespie - Groovin' High -1- [16,24].mid
# 120
# Weimar DB - Don Ellis - I Love You -1- [0,8].mid
# 120
# Weimar DB - Don Ellis - I Love You -2- [20,28].mid
# 120
# Weimar DB - Fats Navarro - Good Bait (1) -1- [0,8].mid
# 120
# Weimar DB - Fats Navarro - Good Bait (2) -1- [0,8].mid
# 120
# Weimar DB - Freddie Hubbard - Maiden Voyage -1- [8,16].mid
# 120
# Weimar DB - Freddie Hubbard - Maiden Voyage -2- [20,28].mid
# 120
# Weimar DB - Freddie Hubbard - Speak No Evil -1- [4,12].mid
# 120
# Weimar DB - George Coleman - Maiden Voyage -1- [20,28].mid
# 120
# Weimar DB - J J Johnson - My Funny Valentine -1- [12,20].mid
# 120
# Weimar DB - J J Johnson - My Funny Valentine -2- [20,28].mid
# 120
# Weimar DB - J J Johnson - Yesterdays -1- [0,8].mid
# 120
# Weimar DB - J J Johnson - Yesterdays -2- [0,8].mid
# 120
# Weimar DB - J J Johnson - Yesterdays -4- [4,12].mid
# 150
# Weimar DB - John Coltrane - Bessie's Blues -1- [0,8].mid
# 150
# Weimar DB - John Coltrane - Bessie's Blues -2- [0,8].mid
# 150
# Weimar DB - John Coltrane - Bessie's Blues -3- [0,8].mid
# 150
# Weimar DB - John Coltrane - Bessie's Blues -4- [0,8].mid
# 150
# Weimar DB - John Coltrane - Bessie's Blues -5- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -1- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -2- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -3- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -4- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -5- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -6- [0,8].mid
# 120
# Weimar DB - John Coltrane - Blue Train -8- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -1- [4,12].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -10- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -11- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -2- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -3- [4,12].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -4- [4,12].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -5- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -6- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -7- [4,12].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -8- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (1) -9- [0,8].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (2) -1- [4,12].mid
# 150
# Weimar DB - John Coltrane - Giant Steps (2) -2- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -1- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -10- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -11- [0,8].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -12- [8,16].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -13- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -14- [20,28].mid
# 150
# Weimar DB - John Coltrane - Impressions (1) -15- [12,20].mid
# 120
# Weimar DB - Lee Morgan - Blue Train -5- [0,8].mid
# 90
# Weimar DB - Lionel Hampton - Memories Of You -1- [16,24].mid
# 150
# Weimar DB - Louis Armstrong - Once In A While -1- [16,24].mid
# 150
# Weimar DB - Miles Davis - Airegin -1- [8,16].mid
# 150
# Weimar DB - Miles Davis - Airegin -2- [24,32].mid
# 150
# Weimar DB - Miles Davis - Airegin -3- [12,20].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -1- [8,16].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -2- [4,12].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -3- [12,20].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -4- [0,8].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -5- [0,8].mid
# 120
# Weimar DB - Miles Davis - Eighty-One -6- [4,12].mid
# 150
# Weimar DB - Miles Davis - Esp -1- [4,12].mid
# 150
# Weimar DB - Miles Davis - Esp -3- [12,20].mid
# 150
# Weimar DB - Miles Davis - Esp -4- [8,16].mid
# 150
# Weimar DB - Miles Davis - Esp -5- [20,28].mid
# 150
# Weimar DB - Miles Davis - Esp -6- [8,16].mid
# 150
# Weimar DB - Miles Davis - Oleo (1) -1- [4,12].mid
# 150
# Weimar DB - Miles Davis - Oleo (1) -2- [8,16].mid
# 150
# Weimar DB - Miles Davis - Oleo (2) -1- [16,24].mid
# 150
# Weimar DB - Miles Davis - Oleo (2) -2- [8,16].mid
# 120
# Weimar DB - Miles Davis - So What -1- [20,28].mid
# 120
# Weimar DB - Miles Davis - So What -2- [12,20].mid
# 150
# Weimar DB - Milt Jackson - All The Things You Are -1- [16,24].mid
# 150
# Weimar DB - Milt Jackson - Bags' Groove -1- [0,8].mid
# 150
# Weimar DB - Milt Jackson - Bemsha Swing -1- [0,8].mid
# 150
# Weimar DB - Milt Jackson - Bemsha Swing -2- [0,8].mid
# 150
# Weimar DB - Milt Jackson - Bemsha Swing -3- [0,8].mid
# 150
# Weimar DB - Milt Jackson - Bemsha Swing -4- [0,8].mid
# 150
# Weimar DB - Milt Jackson - Bemsha Swing -5- [0,8].mid
# 120
# Weimar DB - Milt Jackson - Softly As In A Morning Sunrise -1- [16,24].mid
# 120
# Weimar DB - Milt Jackson - Softly As In A Morning Sunrise -2- [20,28].mid
# 120
# Weimar DB - Milt Jackson - Softly As In A Morning Sunrise -3- [0,8].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -1- [16,24].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -2- [20,28].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -3- [20,28].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -4- [16,24].mid
# 150
# Weimar DB - Clifford Brown - I'll Remember April (2) -2- [16,24].mid
# 120
# Weimar DB - Clifford Brown - Jordu -1- [16,24].mid
# 120
# Weimar DB - Clifford Brown - Jordu -2- [8,16].mid
# 90
# Weimar DB - Coleman Hawkins - Sophisticated Lady -1- [0,8].mid
# 120
# Weimar DB - Curtis Fuller - Blue Train -1- [0,8].mid
# 120
# Weimar DB - Curtis Fuller - Blue Train -2- [0,8].mid
# 120
# Weimar DB - Curtis Fuller - Blue Train -3- [0,8].mid
# 120
# Weimar DB - Curtis Fuller - Blue Train -4- [0,8].mid
# 120
# Weimar DB - Curtis Fuller - Blue Train -5- [0,8].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -1- [12,20].mid
# 150
# Weimar DB - David Liebman - Softly As In A Morning Sunrise -2- [0,8].mid
# 150
# Weimar DB - Pat Metheny - All The Things You Are -6- [24,32].mid
# 150
# Weimar DB - Paul Desmond - Alone Together -1- [0,8].mid
# 150
# Weimar DB - Paul Desmond - Alone Together -2- [0,8].mid
# 150
# Weimar DB - Paul Desmond - Alone Together -3- [28,36].mid
# 120
# Weimar DB - Pepper Adams - A Night In Tunisia -1- [4,12].mid
# 120
# Weimar DB - Pepper Adams - How High The Moon -1- [0,8].mid
# 150
# Weimar DB - Phil Woods - Cottontail -1- [20,28].mid
# 150
# Weimar DB - Phil Woods - Honeysuckle Rose -1- [0,8].mid
# 150
# Weimar DB - Phil Woods - On A Slow Boat To China -1- [8,16].mid
# 150
# Weimar DB - Phil Woods - On A Slow Boat To China -2- [0,8].mid
# 150
# Weimar DB - Phil Woods - On A Slow Boat To China -3- [8,16].mid
# 150
# Weimar DB - Phil Woods - On A Slow Boat To China -4- [8,16].mid
# 150
# Weimar DB - Red Garland - Oleo -2- [4,12].mid
# 150
# Weimar DB - Sidney Bechet - Limehouse Blues -1- [12,20].mid
# 90
# Weimar DB - Sidney Bechet - Summertime -1- [0,8].mid
# 90
# Weimar DB - Sidney Bechet - Summertime -2- [0,8].mid
# 90
# Weimar DB - Sidney Bechet - Summertime -3- [4,12].mid
# 90
# Weimar DB - Sidney Bechet - Summertime -4- [0,8].mid
# 150
# Weimar DB - Sonny Rollins - Airegin -1- [8,16].mid
# 150
# Weimar DB - Sonny Rollins - Airegin -2- [4,12].mid
# 150
# Weimar DB - Sonny Rollins - Airegin -3- [4,12].mid
# 150
# Weimar DB - Sonny Rollins - I'll Remember April -1- [20,28].mid
# 150
# Weimar DB - Sonny Rollins - I'll Remember April -2- [16,24].mid
# 120
# Weimar DB - Stan Getz - My Funny Valentine -1- [4,12].mid
# 120
# Weimar DB - Stan Getz - My Funny Valentine -2- [20,28].mid
# 120
# Weimar DB - Steve Lacy - Alone Together -1- [24,32].mid
# 90
# Weimar DB - Steve Lacy - Ask Me Now -1- [12,20].mid
# 120
# Weimar DB - Steve Lacy - Let's Cool One -1- [12,20].mid
# 120
# Weimar DB - Steve Lacy - Let's Cool One -2- [16,24].mid
# 150
# Weimar DB - Wayne Shorter - Dolores -1- [4,12].mid
# 150
# Weimar DB - Wayne Shorter - Dolores -2- [8,16].mid
# 120
# Weimar DB - Wayne Shorter - Eighty-One -1- [0,8].mid
# 120
# Weimar DB - Wayne Shorter - Eighty-One -2- [0,8].mid
# 120
# Weimar DB - Wayne Shorter - Eighty-One -3- [4,12].mid
# 120
# Weimar DB - Wayne Shorter - Eighty-One -4- [12,20].mid
# 120
# Weimar DB - Wayne Shorter - Eighty-One -5- [12,20].mid
# 150
# Weimar DB - Wayne Shorter - Esp -1- [16,24].mid
# 150
# Weimar DB - Wayne Shorter - Esp -2- [12,20].mid
# 120
# Weimar DB - Wayne Shorter - Speak No Evil -1- [36,44].mid
# 120
# Weimar DB - Wayne Shorter - Speak No Evil -2- [16,24].mid
# 90
# Weimar DB - Woody Shaw - Imagination -1- [16,24].mid
# 150
# Weimar DB - Wynton Marsalis - April In Paris -1- [16,24].mid
# 150
# Weimar DB - Wynton Marsalis - April In Paris -2- [0,8].mid
# 150
# Weimar DB - Zoot Sims - All The Things You Are -1- [4,12].mid
# 150
# Weimar DB - Zoot Sims - Night And Day (1) -1- [28,36].mid
# 150
# Weimar DB - Zoot Sims - Night And Day (1) -2- [12,20].mid
# 150
# Weimar DB - Zoot Sims - Night And Day (2) -1- [4,12].mid
