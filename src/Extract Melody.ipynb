# %%
import pretty_midi as pm
from mido import MidiFile
import music21
import os
from glob import glob
import pandas as pd
import re
import copy

# %%
folder = "../data/Complete Examples/Oocities"

files = [y for x in os.walk(folder) for y in glob(os.path.join(x[0], '*.mid'))]

# %%
files[9]
# Out:
# '../data/Complete Examples/Oocities/Come Rain Or Come Shine.mid'

# %%
melody_names = ['melody', 'melodia', 'melodía', 'lead']
non_melody_names = ['bass', 'bajo', 'basso', 'baixo', 'drum', 'percussion', 'batería', 'bateria', 'chord', 'rhythm',
                     'cymbal', 'clap', 'kick', 'snare', 'hh ', 'hats', 'ride', 'kit']

# %%
def get_channels(m):
    channels = set({})
    for t in m.tracks:
        for m in t:
            if m.type == 'note_on':
                channels.add(m.channel)
                    
    return channels

# %%
def get_programs_mido(m, channels):
    programs = []
    
    for c in channels:
        programs.append(tuple([0, c]))
    
    for t in m.tracks:
        for m in t:
            if m.type == 'program_change':
                programs.append(tuple([m.program, m.channel]))
                
    return programs

# %%
def get_programs_pm(m):
    programs = []
    
    for i in m.instruments:
        programs.append(tuple([i.program, i.is_drum]))
        
    return programs

# %%
def filter_instruments(pm_p):
    filtered_instr = [
        i for i in pm_p.instruments 
        if i.is_drum == False
        and all(
            sub not in i.name.lower() for sub in non_melody_names
        )]
    
    return filtered_instr

# %%
def get_melody_tracks(pm_p):
    melody_tracks = [i for i in pm_p.instruments if 'solo' in i.name.lower()]
    
    if len(melody_tracks) == 0:
        melody_tracks = [
            i for i in pm_p.instruments
            if any(
                sub in i.name.lower() for sub in melody_names
            )]
    
    return melody_tracks

# %%
def extract(file):
    status = 'unprocessed'
    error = None
    
    source = os.path.basename(os.path.dirname(file))
    
    single_melody = False
    multiple_melody = False
    solo_channel = False
    multi_channel = False
    disagreement = False
    single_candidate = False
    
    melody_tracks = []
    filtered_instr = []
    melody_track = None
    
    song_name = os.path.basename(file).replace('.* - ', '').replace('.mid', '')
    song_name = re.sub(r'\([0-9]*\)', '', song_name)

    melody_track_name = None
    
    channels = None
    candidate_names = []
    n_channels = None
    n_instr = None
    mido_p = None
    pm_m = None
    pm_p = None
    midi_type = None
    
    instruments = []
    
    try:
        mido_m = MidiFile(file, clip=True)
        midi_type = mido_m.type

        pm_m = pm.PrettyMIDI(file)

        channels = get_channels(mido_m)
        mido_p = get_programs_mido(mido_m, channels)
        pm_p = get_programs_pm(pm_m)
        
        instruments = pm_m.instruments

        for p, _ in pm_p:
            if p not in [m[0] for m in mido_p]:
                error = 'program mismatch'

        melody_tracks = get_melody_tracks(pm_m)

        n_tracks = len(mido_m.tracks)
        n_channels = len(channels)
        n_instr = len(pm_m.instruments)

        filtered_instr = filter_instruments(pm_m)
        candidate_names = [i.name for i in filtered_instr]

        if n_channels == 1 & n_tracks == 1:
            solo_channel = True
            melody_track = pm_m.instruments[0]    

        if len(melody_tracks) == 1:
            melody_track = melody_tracks[0]
            single_melody = True
            single_candidate = True

        if len(melody_tracks) > 1:
            multiple_melody = True

        if len(filtered_instr) == 1:
            melody_track = filtered_instr[0]
            single_candidate = True

        if len(filtered_instr) > 1:
            multi_channel = True

        if n_channels != n_instr:
            disagreement = True


        if single_melody or solo_channel or single_candidate:
            status = 'processed'
            
            out_path = os.path.join('..', 'data', 'Complete Examples Melodies')
            
           
        if status == 'unprocessed':
            
            out_path = os.path.join('..', 'data', 'Complete Examples Melodies Random')
            
            melody_track  = filtered_instr[0]
           
        
        if melody_track:
            melody_track_name = melody_track.name
            
        if not os.path.exists(os.path.join(out_path, source)):
            os.mkdir(os.path.join(out_path, source))
                
        out_filename = os.path.join(out_path, source, os.path.basename(file))

        pm_melody = copy.deepcopy(pm_m)
        pm_melody.instruments = [melody_track]
        
        print(pm_melody.time_signature_changes)    
        
        pm_melody.write(out_filename) 
            
        
    except Exception as e:
        print(f, e)
        error = e
    
    
    return {
       'filename': file,
       'source': source,
       'song_name': song_name,
       'midi_type' : midi_type,
       'channels': channels,
       'n_channels': n_channels,
       'instruments': instruments,
       'n_instruments': n_instr,
       'programs_mido': mido_p,
       'programs_pm': pm_p,
       'melody_tracks': melody_tracks,
       'melody_track': melody_track,
       'melody_track_name': melody_track_name,
       'candidates': filtered_instr,
       'candidate_names': candidate_names,
       'single_melody': single_melody,
       'multiple_melody': multiple_melody,
       'solo_channel': solo_channel, 
       'single_candidate': single_candidate,
       'multi_channel': multi_channel,
       'disagreement': disagreement,
       'status': status,
       'error': error
   }

# %%
len(files)
# Out:
# 42

# %%
extract(files[9])
# Out:
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# {'filename': '../data/Complete Examples/Oocities/Come Rain Or Come Shine.mid',
#  'source': 'Oocities',
#  'song_name': 'Come Rain Or Come Shine',
#  'midi_type': 1,
#  'channels': {1, 2, 9},
#  'n_channels': 3,
#  'instruments': [Instrument(program=32, is_drum=False, name="Bass"),
#   Instrument(program=0, is_drum=True, name="Drums"),
#   Instrument(program=0, is_drum=False, name="Piano")],
#  'n_instruments': 3,
#  'programs_mido': [(0, 1), (0, 2), (0, 9), (32, 1), (0, 2)],
#  'programs_pm': [(32, False), (0, True), (0, False)],
#  'melody_tracks': [],
#  'melody_track': Instrument(program=0, is_drum=False, name="Piano"),
#  'melody_track_name': 'Piano',
#  'candidates': [Instrument(program=0, is_drum=False, name="Piano")],
#  'candidate_names': ['Piano'],
#  'single_melody': False,
#  'multiple_melody': False,
#  'solo_channel': False,
#  'single_candidate': True,
#  'multi_channel': False,
#  'disagreement': False,
#  'status': 'processed',
#  'error': None}

# %%
f='/media/manu/Data/PycharmProjects/thesis/data/Complete Examples Melodies/Oocities/Come Rain Or Come Shine.mid'
m = MidiFile(f, clip=True)

print(m)

for i, track in enumerate(m.tracks):
        for msg in track:
            if msg.type == 'time_signature':
                print(msg)
# Out:
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=375000, time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('key_signature', key='F', time=0),
#     MetaMessage('end_of_track', time=1)]),
#   MidiTrack([
#     MetaMessage('track_name', name='Piano', time=0),
#     Message('program_change', channel=0, program=0, time=0),
#     Message('note_on', channel=0, note=60, velocity=83, time=56),
#     Message('note_on', channel=0, note=64, velocity=77, time=2),
#     Message('note_on', channel=0, note=62, velocity=73, time=1),
#     Message('note_on', channel=0, note=67, velocity=77, time=3),
#     Message('note_on', channel=0, note=57, velocity=56, time=4),
#     Message('note_on', channel=0, note=53, velocity=59, time=6),
#     Message('note_on', channel=0, note=64, velocity=0, time=78),
#     Message('note_on', channel=0, note=57, velocity=0, time=8),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=1),
#     Message('note_on', channel=0, note=60, velocity=0, time=27),
#     Message('note_on', channel=0, note=53, velocity=0, time=23),
#     Message('note_on', channel=0, note=67, velocity=101, time=565),
#     Message('note_on', channel=0, note=57, velocity=89, time=7),
#     Message('note_on', channel=0, note=64, velocity=93, time=0),
#     Message('note_on', channel=0, note=60, velocity=88, time=3),
#     Message('note_on', channel=0, note=53, velocity=84, time=1),
#     Message('note_on', channel=0, note=62, velocity=86, time=0),
#     Message('note_on', channel=0, note=60, velocity=0, time=151),
#     Message('note_on', channel=0, note=64, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=53, velocity=0, time=6),
#     Message('note_on', channel=0, note=62, velocity=0, time=10),
#     Message('note_on', channel=0, note=57, velocity=0, time=16),
#     Message('note_on', channel=0, note=57, velocity=26, time=51),
#     Message('note_on', channel=0, note=67, velocity=51, time=13),
#     Message('note_on', channel=0, note=60, velocity=53, time=4),
#     Message('note_on', channel=0, note=53, velocity=49, time=1),
#     Message('note_on', channel=0, note=64, velocity=49, time=17),
#     Message('note_on', channel=0, note=62, velocity=50, time=1),
#     Message('note_on', channel=0, note=67, velocity=0, time=105),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=62, velocity=0, time=4),
#     Message('note_on', channel=0, note=60, velocity=0, time=18),
#     Message('note_on', channel=0, note=53, velocity=0, time=9),
#     Message('note_on', channel=0, note=57, velocity=0, time=18),
#     Message('note_on', channel=0, note=62, velocity=49, time=78),
#     Message('note_on', channel=0, note=64, velocity=57, time=14),
#     Message('note_on', channel=0, note=67, velocity=57, time=0),
#     Message('note_on', channel=0, note=57, velocity=48, time=5),
#     Message('note_on', channel=0, note=60, velocity=37, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=69),
#     Message('note_on', channel=0, note=67, velocity=0, time=5),
#     Message('note_on', channel=0, note=62, velocity=0, time=10),
#     Message('note_on', channel=0, note=60, velocity=0, time=4),
#     Message('note_on', channel=0, note=57, velocity=0, time=7),
#     Message('note_on', channel=0, note=67, velocity=64, time=324),
#     Message('note_on', channel=0, note=62, velocity=59, time=1),
#     Message('note_on', channel=0, note=64, velocity=59, time=5),
#     Message('note_on', channel=0, note=59, velocity=53, time=2),
#     Message('note_on', channel=0, note=57, velocity=43, time=8),
#     Message('note_on', channel=0, note=53, velocity=45, time=5),
#     Message('note_on', channel=0, note=64, velocity=0, time=62),
#     Message('note_on', channel=0, note=62, velocity=0, time=14),
#     Message('note_on', channel=0, note=67, velocity=0, time=7),
#     Message('note_on', channel=0, note=57, velocity=0, time=13),
#     Message('note_on', channel=0, note=53, velocity=0, time=7),
#     Message('note_on', channel=0, note=59, velocity=0, time=0),
#     Message('note_on', channel=0, note=59, velocity=58, time=307),
#     Message('note_on', channel=0, note=67, velocity=58, time=1),
#     Message('note_on', channel=0, note=62, velocity=53, time=7),
#     Message('note_on', channel=0, note=64, velocity=55, time=2),
#     Message('note_on', channel=0, note=57, velocity=50, time=13),
#     Message('note_on', channel=0, note=53, velocity=52, time=9),
#     Message('note_on', channel=0, note=59, velocity=0, time=337),
#     Message('note_on', channel=0, note=67, velocity=0, time=3),
#     Message('note_on', channel=0, note=64, velocity=0, time=2),
#     Message('note_on', channel=0, note=62, velocity=0, time=2),
#     Message('note_on', channel=0, note=53, velocity=0, time=16),
#     Message('note_on', channel=0, note=57, velocity=0, time=14),
#     Message('note_on', channel=0, note=59, velocity=50, time=79),
#     Message('note_on', channel=0, note=57, velocity=53, time=1),
#     Message('note_on', channel=0, note=67, velocity=50, time=9),
#     Message('note_on', channel=0, note=53, velocity=48, time=9),
#     Message('note_on', channel=0, note=64, velocity=55, time=1),
#     Message('note_on', channel=0, note=62, velocity=40, time=4),
#     Message('note_on', channel=0, note=59, velocity=0, time=119),
#     Message('note_on', channel=0, note=64, velocity=0, time=9),
#     Message('note_on', channel=0, note=67, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=25, time=82),
#     Message('note_on', channel=0, note=67, velocity=31, time=22),
#     Message('note_on', channel=0, note=64, velocity=27, time=7),
#     Message('note_on', channel=0, note=59, velocity=0, time=114),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=67, velocity=0, time=3),
#     Message('note_on', channel=0, note=62, velocity=0, time=17),
#     Message('note_on', channel=0, note=57, velocity=0, time=6),
#     Message('note_on', channel=0, note=57, velocity=20, time=65),
#     Message('note_on', channel=0, note=59, velocity=43, time=5),
#     Message('note_on', channel=0, note=67, velocity=52, time=22),
#     Message('note_on', channel=0, note=64, velocity=55, time=8),
#     Message('note_on', channel=0, note=62, velocity=48, time=1),
#     Message('note_on', channel=0, note=59, velocity=0, time=101),
#     Message('note_on', channel=0, note=64, velocity=0, time=16),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=67, velocity=0, time=2),
#     Message('note_on', channel=0, note=53, velocity=0, time=3),
#     Message('note_on', channel=0, note=62, velocity=0, time=18),
#     Message('note_on', channel=0, note=57, velocity=64, time=68),
#     Message('note_on', channel=0, note=67, velocity=66, time=0),
#     Message('note_on', channel=0, note=53, velocity=66, time=2),
#     Message('note_on', channel=0, note=59, velocity=70, time=7),
#     Message('note_on', channel=0, note=64, velocity=70, time=1),
#     Message('note_on', channel=0, note=62, velocity=71, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=101),
#     Message('note_on', channel=0, note=59, velocity=0, time=26),
#     Message('note_on', channel=0, note=62, velocity=0, time=1),
#     Message('note_on', channel=0, note=67, velocity=0, time=6),
#     Message('note_on', channel=0, note=53, velocity=0, time=7),
#     Message('note_on', channel=0, note=57, velocity=0, time=4),
#     Message('note_on', channel=0, note=67, velocity=69, time=62),
#     Message('note_on', channel=0, note=62, velocity=54, time=8),
#     Message('note_on', channel=0, note=64, velocity=50, time=8),
#     Message('note_on', channel=0, note=59, velocity=53, time=9),
#     Message('note_on', channel=0, note=57, velocity=52, time=2),
#     Message('note_on', channel=0, note=53, velocity=49, time=16),
#     Message('note_on', channel=0, note=53, velocity=0, time=85),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=2),
#     Message('note_on', channel=0, note=62, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=0, time=3),
#     Message('note_on', channel=0, note=57, velocity=0, time=6),
#     Message('note_on', channel=0, note=57, velocity=48, time=114),
#     Message('note_on', channel=0, note=60, velocity=78, time=18),
#     Message('note_on', channel=0, note=53, velocity=62, time=2),
#     Message('note_on', channel=0, note=67, velocity=58, time=12),
#     Message('note_on', channel=0, note=64, velocity=72, time=5),
#     Message('note_on', channel=0, note=62, velocity=60, time=3),
#     Message('note_on', channel=0, note=60, velocity=0, time=106),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=4),
#     Message('note_on', channel=0, note=62, velocity=0, time=10),
#     Message('note_on', channel=0, note=57, velocity=0, time=8),
#     Message('note_on', channel=0, note=53, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=83, time=341),
#     Message('note_on', channel=0, note=67, velocity=92, time=4),
#     Message('note_on', channel=0, note=60, velocity=90, time=5),
#     Message('note_on', channel=0, note=62, velocity=84, time=0),
#     Message('note_on', channel=0, note=64, velocity=91, time=1),
#     Message('note_on', channel=0, note=53, velocity=78, time=3),
#     Message('note_on', channel=0, note=53, velocity=0, time=368),
#     Message('note_on', channel=0, note=53, velocity=60, time=87),
#     Message('note_on', channel=0, note=62, velocity=0, time=99),
#     Message('note_on', channel=0, note=60, velocity=0, time=6),
#     Message('note_on', channel=0, note=67, velocity=0, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=11),
#     Message('note_on', channel=0, note=53, velocity=0, time=30),
#     Message('note_on', channel=0, note=67, velocity=63, time=139),
#     Message('note_on', channel=0, note=57, velocity=53, time=2),
#     Message('note_on', channel=0, note=60, velocity=63, time=3),
#     Message('note_on', channel=0, note=64, velocity=64, time=5),
#     Message('note_on', channel=0, note=62, velocity=57, time=1),
#     Message('note_on', channel=0, note=53, velocity=44, time=5),
#     Message('note_on', channel=0, note=64, velocity=0, time=82),
#     Message('note_on', channel=0, note=62, velocity=0, time=8),
#     Message('note_on', channel=0, note=67, velocity=0, time=10),
#     Message('note_on', channel=0, note=60, velocity=0, time=8),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=53, velocity=0, time=9),
#     Message('note_on', channel=0, note=67, velocity=63, time=306),
#     Message('note_on', channel=0, note=59, velocity=64, time=13),
#     Message('note_on', channel=0, note=64, velocity=57, time=6),
#     Message('note_on', channel=0, note=62, velocity=48, time=1),
#     Message('note_on', channel=0, note=53, velocity=51, time=2),
#     Message('note_on', channel=0, note=57, velocity=50, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=84),
#     Message('note_on', channel=0, note=62, velocity=0, time=4),
#     Message('note_on', channel=0, note=67, velocity=0, time=18),
#     Message('note_on', channel=0, note=59, velocity=0, time=24),
#     Message('note_on', channel=0, note=57, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=18),
#     Message('note_on', channel=0, note=67, velocity=81, time=292),
#     Message('note_on', channel=0, note=59, velocity=78, time=1),
#     Message('note_on', channel=0, note=57, velocity=65, time=1),
#     Message('note_on', channel=0, note=62, velocity=69, time=8),
#     Message('note_on', channel=0, note=64, velocity=75, time=3),
#     Message('note_on', channel=0, note=53, velocity=62, time=2),
#     Message('note_on', channel=0, note=53, velocity=0, time=314),
#     Message('note_on', channel=0, note=59, velocity=0, time=5),
#     Message('note_on', channel=0, note=62, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=0, time=15),
#     Message('note_on', channel=0, note=57, velocity=0, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=57, velocity=43, time=119),
#     Message('note_on', channel=0, note=59, velocity=62, time=8),
#     Message('note_on', channel=0, note=67, velocity=69, time=9),
#     Message('note_on', channel=0, note=53, velocity=57, time=3),
#     Message('note_on', channel=0, note=64, velocity=58, time=14),
#     Message('note_on', channel=0, note=62, velocity=61, time=2),
#     Message('note_on', channel=0, note=59, velocity=0, time=103),
#     Message('note_on', channel=0, note=64, velocity=0, time=6),
#     Message('note_on', channel=0, note=62, velocity=0, time=10),
#     Message('note_on', channel=0, note=57, velocity=0, time=10),
#     Message('note_on', channel=0, note=67, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=4),
#     Message('note_on', channel=0, note=67, velocity=42, time=102),
#     Message('note_on', channel=0, note=62, velocity=35, time=12),
#     Message('note_on', channel=0, note=59, velocity=51, time=2),
#     Message('note_on', channel=0, note=64, velocity=54, time=1),
#     Message('note_on', channel=0, note=57, velocity=50, time=3),
#     Message('note_on', channel=0, note=53, velocity=39, time=4),
#     Message('note_on', channel=0, note=64, velocity=0, time=100),
#     Message('note_on', channel=0, note=62, velocity=0, time=10),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=59, velocity=0, time=8),
#     Message('note_on', channel=0, note=57, velocity=0, time=19),
#     Message('note_on', channel=0, note=53, velocity=0, time=10),
#     Message('note_on', channel=0, note=67, velocity=96, time=291),
#     Message('note_on', channel=0, note=57, velocity=86, time=1),
#     Message('note_on', channel=0, note=59, velocity=93, time=1),
#     Message('note_on', channel=0, note=64, velocity=94, time=3),
#     Message('note_on', channel=0, note=62, velocity=86, time=1),
#     Message('note_on', channel=0, note=53, velocity=80, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=354),
#     Message('note_on', channel=0, note=64, velocity=0, time=40),
#     Message('note_on', channel=0, note=62, velocity=0, time=15),
#     Message('note_on', channel=0, note=59, velocity=0, time=2),
#     Message('note_on', channel=0, note=67, velocity=0, time=30),
#     Message('note_on', channel=0, note=53, velocity=50, time=17),
#     Message('note_on', channel=0, note=57, velocity=0, time=19),
#     Message('note_on', channel=0, note=53, velocity=0, time=77),
#     Message('note_on', channel=0, note=61, velocity=75, time=161),
#     Message('note_on', channel=0, note=57, velocity=58, time=8),
#     Message('note_on', channel=0, note=67, velocity=72, time=9),
#     Message('note_on', channel=0, note=64, velocity=72, time=10),
#     Message('note_on', channel=0, note=53, velocity=38, time=23),
#     Message('note_on', channel=0, note=61, velocity=0, time=87),
#     Message('note_on', channel=0, note=64, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=4),
#     Message('note_on', channel=0, note=67, velocity=0, time=3),
#     Message('note_on', channel=0, note=57, velocity=0, time=28),
#     Message('note_on', channel=0, note=61, velocity=101, time=249),
#     Message('note_on', channel=0, note=57, velocity=71, time=8),
#     Message('note_on', channel=0, note=67, velocity=89, time=3),
#     Message('note_on', channel=0, note=64, velocity=92, time=7),
#     Message('note_on', channel=0, note=53, velocity=61, time=8),
#     Message('note_on', channel=0, note=53, velocity=0, time=189),
#     Message('note_on', channel=0, note=57, velocity=0, time=13),
#     Message('note_on', channel=0, note=64, velocity=0, time=4),
#     Message('note_on', channel=0, note=67, velocity=0, time=9),
#     Message('note_on', channel=0, note=61, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=62, time=81),
#     Message('note_on', channel=0, note=57, velocity=46, time=11),
#     Message('note_on', channel=0, note=64, velocity=65, time=1),
#     Message('note_on', channel=0, note=60, velocity=56, time=9),
#     Message('note_on', channel=0, note=53, velocity=44, time=14),
#     Message('note_on', channel=0, note=60, velocity=0, time=255),
#     Message('note_on', channel=0, note=53, velocity=0, time=9),
#     Message('note_on', channel=0, note=57, velocity=0, time=6),
#     Message('note_on', channel=0, note=64, velocity=0, time=9),
#     Message('note_on', channel=0, note=67, velocity=0, time=6),
#     Message('note_on', channel=0, note=60, velocity=65, time=113),
#     Message('note_on', channel=0, note=57, velocity=56, time=10),
#     Message('note_on', channel=0, note=53, velocity=44, time=11),
#     Message('note_on', channel=0, note=67, velocity=61, time=0),
#     Message('note_on', channel=0, note=64, velocity=70, time=1),
#     Message('note_on', channel=0, note=60, velocity=0, time=95),
#     Message('note_on', channel=0, note=57, velocity=0, time=9),
#     Message('note_on', channel=0, note=53, velocity=0, time=20),
#     Message('note_on', channel=0, note=64, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=0, time=1),
#     Message('note_on', channel=0, note=53, velocity=40, time=111),
#     Message('note_on', channel=0, note=57, velocity=60, time=0),
#     Message('note_on', channel=0, note=59, velocity=63, time=12),
#     Message('note_on', channel=0, note=67, velocity=54, time=4),
#     Message('note_on', channel=0, note=64, velocity=57, time=2),
#     Message('note_on', channel=0, note=64, velocity=0, time=94),
#     Message('note_on', channel=0, note=59, velocity=0, time=15),
#     Message('note_on', channel=0, note=57, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=0, time=5),
#     Message('note_on', channel=0, note=53, velocity=0, time=7),
#     Message('note_on', channel=0, note=67, velocity=76, time=302),
#     Message('note_on', channel=0, note=64, velocity=79, time=7),
#     Message('note_on', channel=0, note=57, velocity=58, time=1),
#     Message('note_on', channel=0, note=59, velocity=72, time=1),
#     Message('note_on', channel=0, note=53, velocity=49, time=21),
#     Message('note_on', channel=0, note=64, velocity=0, time=107),
#     Message('note_on', channel=0, note=57, velocity=0, time=9),
#     Message('note_on', channel=0, note=59, velocity=0, time=7),
#     Message('note_on', channel=0, note=67, velocity=0, time=1),
#     Message('note_on', channel=0, note=53, velocity=0, time=14),
#     Message('note_on', channel=0, note=62, velocity=56, time=307),
#     Message('note_on', channel=0, note=53, velocity=38, time=7),
#     Message('note_on', channel=0, note=62, velocity=0, time=69),
#     Message('note_on', channel=0, note=53, velocity=0, time=23),
#     Message('note_on', channel=0, note=67, velocity=73, time=112),
#     Message('note_on', channel=0, note=59, velocity=62, time=4),
#     Message('note_on', channel=0, note=53, velocity=40, time=8),
#     Message('note_on', channel=0, note=57, velocity=55, time=1),
#     Message('note_on', channel=0, note=64, velocity=69, time=4),
#     Message('note_on', channel=0, note=59, velocity=0, time=127),
#     Message('note_on', channel=0, note=57, velocity=0, time=11),
#     Message('note_on', channel=0, note=64, velocity=0, time=7),
#     Message('note_on', channel=0, note=53, velocity=0, time=10),
#     Message('note_on', channel=0, note=67, velocity=0, time=15),
#     Message('note_on', channel=0, note=62, velocity=59, time=69),
#     Message('note_on', channel=0, note=59, velocity=34, time=29),
#     Message('note_on', channel=0, note=57, velocity=28, time=18),
#     Message('note_on', channel=0, note=53, velocity=17, time=1),
#     Message('note_on', channel=0, note=62, velocity=0, time=47),
#     Message('note_on', channel=0, note=57, velocity=0, time=33),
#     Message('note_on', channel=0, note=59, velocity=0, time=9),
#     Message('note_on', channel=0, note=53, velocity=0, time=12),
#     Message('note_on', channel=0, note=59, velocity=60, time=73),
#     Message('note_on', channel=0, note=67, velocity=72, time=1),
#     Message('note_on', channel=0, note=64, velocity=77, time=4),
#     Message('note_on', channel=0, note=57, velocity=58, time=3),
#     Message('note_on', channel=0, note=53, velocity=42, time=5),
#     Message('note_on', channel=0, note=67, velocity=0, time=126),
#     Message('note_on', channel=0, note=64, velocity=0, time=2),
#     Message('note_on', channel=0, note=59, velocity=0, time=2),
#     Message('note_on', channel=0, note=57, velocity=0, time=8),
#     Message('note_on', channel=0, note=53, velocity=0, time=17),
#     Message('note_on', channel=0, note=53, velocity=46, time=108),
#     Message('note_on', channel=0, note=57, velocity=27, time=35),
#     Message('note_on', channel=0, note=57, velocity=0, time=58),
#     Message('note_on', channel=0, note=53, velocity=0, time=19),
#     Message('note_on', channel=0, note=67, velocity=66, time=80),
#     Message('note_on', channel=0, note=57, velocity=46, time=13),
#     Message('note_on', channel=0, note=64, velocity=67, time=8),
#     Message('note_on', channel=0, note=60, velocity=70, time=1),
#     Message('note_on', channel=0, note=53, velocity=40, time=17),
#     Message('note_on', channel=0, note=64, velocity=0, time=87),
#     Message('note_on', channel=0, note=67, velocity=0, time=14),
#     Message('note_on', channel=0, note=53, velocity=0, time=9),
#     Message('note_on', channel=0, note=60, velocity=0, time=6),
#     Message('note_on', channel=0, note=57, velocity=0, time=3),
#     Message('note_on', channel=0, note=67, velocity=66, time=304),
#     Message('note_on', channel=0, note=60, velocity=57, time=16),
#     Message('note_on', channel=0, note=64, velocity=65, time=5),
#     Message('note_on', channel=0, note=57, velocity=47, time=1),
#     Message('note_on', channel=0, note=53, velocity=48, time=23),
#     Message('control_change', channel=0, control=64, value=127, time=452),
#     Message('note_on', channel=0, note=60, velocity=0, time=154),
#     Message('note_on', channel=0, note=67, velocity=0, time=6),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=4),
#     Message('control_change', channel=0, control=64, value=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=13),
#     Message('note_on', channel=0, note=60, velocity=45, time=101),
#     Message('note_on', channel=0, note=53, velocity=37, time=4),
#     Message('note_on', channel=0, note=57, velocity=38, time=1),
#     Message('note_on', channel=0, note=67, velocity=64, time=9),
#     Message('note_on', channel=0, note=64, velocity=57, time=9),
#     Message('control_change', channel=0, control=64, value=127, time=133),
#     Message('note_on', channel=0, note=64, velocity=0, time=28),
#     Message('note_on', channel=0, note=60, velocity=0, time=37),
#     Message('note_on', channel=0, note=67, velocity=0, time=2),
#     Message('note_on', channel=0, note=53, velocity=0, time=50),
#     Message('note_on', channel=0, note=57, velocity=0, time=79),
#     Message('control_change', channel=0, control=64, value=0, time=142),
#     Message('note_on', channel=0, note=62, velocity=63, time=24),
#     Message('note_on', channel=0, note=69, velocity=67, time=0),
#     Message('note_on', channel=0, note=53, velocity=48, time=32),
#     Message('note_on', channel=0, note=58, velocity=71, time=0),
#     Message('control_change', channel=0, control=64, value=127, time=212),
#     Message('note_on', channel=0, note=58, velocity=0, time=24),
#     Message('note_on', channel=0, note=62, velocity=0, time=15),
#     Message('note_on', channel=0, note=53, velocity=0, time=11),
#     Message('note_on', channel=0, note=69, velocity=0, time=89),
#     Message('note_on', channel=0, note=62, velocity=60, time=83),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=72, velocity=75, time=2),
#     Message('note_on', channel=0, note=53, velocity=57, time=3),
#     Message('note_on', channel=0, note=58, velocity=68, time=6),
#     Message('note_on', channel=0, note=58, velocity=0, time=199),
#     Message('control_change', channel=0, control=64, value=127, time=1),
#     Message('note_on', channel=0, note=62, velocity=0, time=9),
#     Message('note_on', channel=0, note=53, velocity=0, time=19),
#     Message('note_on', channel=0, note=72, velocity=0, time=187),
#     Message('control_change', channel=0, control=64, value=0, time=54),
#     Message('note_on', channel=0, note=61, velocity=83, time=1),
#     Message('note_on', channel=0, note=77, velocity=89, time=1),
#     Message('note_on', channel=0, note=58, velocity=74, time=29),
#     Message('note_on', channel=0, note=52, velocity=48, time=12),
#     Message('control_change', channel=0, control=64, value=127, time=196),
#     Message('note_on', channel=0, note=61, velocity=0, time=40),
#     Message('note_on', channel=0, note=58, velocity=0, time=9),
#     Message('note_on', channel=0, note=52, velocity=0, time=10),
#     Message('note_on', channel=0, note=77, velocity=0, time=109),
#     Message('control_change', channel=0, control=64, value=0, time=43),
#     Message('note_on', channel=0, note=80, velocity=81, time=12),
#     Message('note_on', channel=0, note=61, velocity=72, time=8),
#     Message('note_on', channel=0, note=58, velocity=72, time=14),
#     Message('note_on', channel=0, note=52, velocity=50, time=6),
#     Message('note_on', channel=0, note=81, velocity=66, time=67),
#     Message('note_on', channel=0, note=80, velocity=0, time=2),
#     Message('note_on', channel=0, note=52, velocity=0, time=146),
#     Message('control_change', channel=0, control=64, value=127, time=13),
#     Message('note_on', channel=0, note=58, velocity=0, time=5),
#     Message('note_on', channel=0, note=81, velocity=0, time=47),
#     Message('note_on', channel=0, note=61, velocity=0, time=15),
#     Message('note_on', channel=0, note=61, velocity=69, time=189),
#     Message('note_on', channel=0, note=61, velocity=0, time=109),
#     Message('control_change', channel=0, control=64, value=0, time=128),
#     Message('note_on', channel=0, note=64, velocity=71, time=1),
#     Message('note_on', channel=0, note=57, velocity=58, time=18),
#     Message('note_on', channel=0, note=62, velocity=60, time=3),
#     Message('note_on', channel=0, note=62, velocity=0, time=199),
#     Message('note_on', channel=0, note=64, velocity=0, time=5),
#     Message('note_on', channel=0, note=57, velocity=0, time=7),
#     Message('note_on', channel=0, note=69, velocity=93, time=30),
#     Message('note_on', channel=0, note=69, velocity=0, time=132),
#     Message('note_on', channel=0, note=69, velocity=64, time=81),
#     Message('note_on', channel=0, note=69, velocity=0, time=136),
#     Message('note_on', channel=0, note=64, velocity=60, time=130),
#     Message('note_on', channel=0, note=62, velocity=48, time=5),
#     Message('note_on', channel=0, note=57, velocity=51, time=16),
#     Message('note_on', channel=0, note=62, velocity=0, time=105),
#     Message('note_on', channel=0, note=57, velocity=0, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=16),
#     Message('note_on', channel=0, note=69, velocity=61, time=65),
#     Message('note_on', channel=0, note=57, velocity=57, time=224),
#     Message('note_on', channel=0, note=64, velocity=42, time=21),
#     Message('note_on', channel=0, note=62, velocity=40, time=3),
#     Message('note_on', channel=0, note=69, velocity=0, time=127),
#     Message('note_on', channel=0, note=57, velocity=0, time=4),
#     Message('note_on', channel=0, note=64, velocity=0, time=33),
#     Message('note_on', channel=0, note=62, velocity=0, time=9),
#     Message('note_on', channel=0, note=69, velocity=69, time=80),
#     Message('note_on', channel=0, note=69, velocity=0, time=180),
#     Message('note_on', channel=0, note=69, velocity=71, time=70),
#     Message('note_on', channel=0, note=69, velocity=0, time=112),
#     Message('note_on', channel=0, note=66, velocity=47, time=114),
#     Message('note_on', channel=0, note=62, velocity=40, time=19),
#     Message('note_on', channel=0, note=55, velocity=35, time=22),
#     Message('note_on', channel=0, note=69, velocity=80, time=179),
#     Message('note_on', channel=0, note=69, velocity=0, time=118),
#     Message('note_on', channel=0, note=69, velocity=61, time=134),
#     Message('note_on', channel=0, note=62, velocity=0, time=26),
#     Message('note_on', channel=0, note=55, velocity=0, time=1),
#     Message('note_on', channel=0, note=66, velocity=0, time=65),
#     Message('note_on', channel=0, note=69, velocity=0, time=68),
#     Message('note_on', channel=0, note=61, velocity=66, time=77),
#     Message('note_on', channel=0, note=65, velocity=63, time=14),
#     Message('note_on', channel=0, note=55, velocity=51, time=27),
#     Message('note_on', channel=0, note=69, velocity=86, time=199),
#     Message('note_on', channel=0, note=55, velocity=0, time=98),
#     Message('note_on', channel=0, note=61, velocity=0, time=9),
#     Message('note_on', channel=0, note=65, velocity=0, time=9),
#     Message('note_on', channel=0, note=61, velocity=48, time=62),
#     Message('note_on', channel=0, note=65, velocity=43, time=14),
#     Message('note_on', channel=0, note=55, velocity=49, time=22),
#     Message('note_on', channel=0, note=69, velocity=0, time=83),
#     Message('note_on', channel=0, note=69, velocity=83, time=172),
#     Message('note_on', channel=0, note=65, velocity=0, time=114),
#     Message('note_on', channel=0, note=55, velocity=0, time=102),
#     Message('note_on', channel=0, note=69, velocity=0, time=12),
#     Message('note_on', channel=0, note=58, velocity=75, time=22),
#     Message('note_on', channel=0, note=61, velocity=0, time=35),
#     Message('note_on', channel=0, note=58, velocity=0, time=57),
#     Message('note_on', channel=0, note=68, velocity=79, time=89),
#     Message('note_on', channel=0, note=64, velocity=49, time=30),
#     Message('note_on', channel=0, note=60, velocity=41, time=14),
#     Message('note_on', channel=0, note=53, velocity=37, time=14),
#     Message('note_on', channel=0, note=69, velocity=63, time=47),
#     Message('note_on', channel=0, note=68, velocity=0, time=7),
#     Message('note_on', channel=0, note=69, velocity=0, time=190),
#     Message('note_on', channel=0, note=65, velocity=67, time=18),
#     Message('note_on', channel=0, note=60, velocity=0, time=110),
#     Message('note_on', channel=0, note=65, velocity=0, time=30),
#     Message('note_on', channel=0, note=65, velocity=82, time=73),
#     Message('note_on', channel=0, note=65, velocity=0, time=146),
#     Message('note_on', channel=0, note=60, velocity=52, time=121),
#     Message('note_on', channel=0, note=53, velocity=0, time=30),
#     Message('note_on', channel=0, note=60, velocity=0, time=68),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=65, velocity=85, time=79),
#     Message('note_on', channel=0, note=61, velocity=78, time=270),
#     Message('note_on', channel=0, note=55, velocity=50, time=33),
#     Message('note_on', channel=0, note=61, velocity=0, time=69),
#     Message('note_on', channel=0, note=55, velocity=0, time=22),
#     Message('note_on', channel=0, note=60, velocity=62, time=370),
#     Message('note_on', channel=0, note=64, velocity=58, time=4),
#     Message('note_on', channel=0, note=53, velocity=54, time=6),
#     Message('note_on', channel=0, note=60, velocity=0, time=92),
#     Message('note_on', channel=0, note=64, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=68),
#     Message('note_on', channel=0, note=60, velocity=57, time=274),
#     Message('note_on', channel=0, note=53, velocity=53, time=3),
#     Message('note_on', channel=0, note=64, velocity=53, time=5),
#     Message('note_on', channel=0, note=64, velocity=0, time=105),
#     Message('note_on', channel=0, note=60, velocity=0, time=11),
#     Message('note_on', channel=0, note=53, velocity=0, time=44),
#     Message('note_on', channel=0, note=53, velocity=65, time=280),
#     Message('note_on', channel=0, note=53, velocity=0, time=88),
#     Message('note_on', channel=0, note=60, velocity=53, time=177),
#     Message('note_on', channel=0, note=64, velocity=55, time=3),
#     Message('note_on', channel=0, note=53, velocity=55, time=1),
#     Message('note_on', channel=0, note=64, velocity=0, time=102),
#     Message('note_on', channel=0, note=60, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=32),
#     Message('note_on', channel=0, note=60, velocity=61, time=335),
#     Message('note_on', channel=0, note=53, velocity=60, time=6),
#     Message('note_on', channel=0, note=64, velocity=65, time=1),
#     Message('note_on', channel=0, note=64, velocity=0, time=118),
#     Message('note_on', channel=0, note=60, velocity=0, time=15),
#     Message('note_on', channel=0, note=53, velocity=0, time=56),
#     Message('note_on', channel=0, note=60, velocity=50, time=287),
#     Message('note_on', channel=0, note=53, velocity=49, time=3),
#     Message('note_on', channel=0, note=64, velocity=53, time=0),
#     Message('note_on', channel=0, note=57, velocity=55, time=7),
#     Message('note_on', channel=0, note=65, velocity=0, time=101),
#     Message('control_change', channel=0, control=64, value=127, time=22),
#     Message('note_on', channel=0, note=69, velocity=95, time=151),
#     Message('note_on', channel=0, note=69, velocity=0, time=144),
#     Message('note_on', channel=0, note=60, velocity=0, time=67),
#     Message('note_on', channel=0, note=69, velocity=73, time=17),
#     Message('note_on', channel=0, note=64, velocity=0, time=3),
#     Message('note_on', channel=0, note=53, velocity=0, time=5),
#     Message('note_on', channel=0, note=57, velocity=0, time=47),
#     Message('note_on', channel=0, note=69, velocity=0, time=115),
#     Message('note_on', channel=0, note=64, velocity=61, time=71),
#     Message('note_on', channel=0, note=69, velocity=65, time=6),
#     Message('note_on', channel=0, note=59, velocity=50, time=5),
#     Message('note_on', channel=0, note=57, velocity=48, time=3),
#     Message('control_change', channel=0, control=64, value=0, time=28),
#     Message('note_on', channel=0, note=53, velocity=20, time=14),
#     Message('note_on', channel=0, note=59, velocity=0, time=49),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=4),
#     Message('note_on', channel=0, note=69, velocity=0, time=6),
#     Message('note_on', channel=0, note=53, velocity=0, time=1),
#     Message('note_on', channel=0, note=69, velocity=87, time=333),
#     Message('note_on', channel=0, note=59, velocity=65, time=8),
#     Message('note_on', channel=0, note=64, velocity=70, time=14),
#     Message('note_on', channel=0, note=57, velocity=60, time=1),
#     Message('note_on', channel=0, note=53, velocity=64, time=7),
#     Message('control_change', channel=0, control=64, value=127, time=56),
#     Message('note_on', channel=0, note=59, velocity=0, time=127),
#     Message('note_on', channel=0, note=64, velocity=0, time=15),
#     Message('note_on', channel=0, note=57, velocity=0, time=51),
#     Message('note_on', channel=0, note=69, velocity=0, time=11),
#     Message('note_on', channel=0, note=53, velocity=0, time=6),
#     Message('control_change', channel=0, control=64, value=0, time=156),
#     Message('note_on', channel=0, note=57, velocity=80, time=9),
#     Message('note_on', channel=0, note=58, velocity=94, time=4),
#     Message('note_on', channel=0, note=62, velocity=89, time=0),
#     Message('note_on', channel=0, note=72, velocity=111, time=5),
#     Message('note_on', channel=0, note=53, velocity=77, time=3),
#     Message('control_change', channel=0, control=64, value=127, time=262),
#     Message('note_on', channel=0, note=72, velocity=0, time=184),
#     Message('note_on', channel=0, note=69, velocity=91, time=48),
#     Message('control_change', channel=0, control=64, value=0, time=23),
#     Message('note_on', channel=0, note=69, velocity=0, time=100),
#     Message('note_on', channel=0, note=69, velocity=63, time=75),
#     Message('note_on', channel=0, note=58, velocity=0, time=91),
#     Message('control_change', channel=0, control=64, value=127, time=29),
#     Message('note_on', channel=0, note=57, velocity=0, time=3),
#     Message('note_on', channel=0, note=69, velocity=0, time=88),
#     Message('note_on', channel=0, note=57, velocity=62, time=64),
#     Message('control_change', channel=0, control=64, value=0, time=2),
#     Message('note_on', channel=0, note=53, velocity=0, time=44),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=57, velocity=0, time=42),
#     Message('note_on', channel=0, note=69, velocity=81, time=106),
#     Message('note_on', channel=0, note=58, velocity=64, time=251),
#     Message('note_on', channel=0, note=62, velocity=53, time=3),
#     Message('note_on', channel=0, note=52, velocity=48, time=34),
#     Message('note_on', channel=0, note=58, velocity=0, time=114),
#     Message('note_on', channel=0, note=62, velocity=0, time=40),
#     Message('note_on', channel=0, note=52, velocity=0, time=77),
#     Message('control_change', channel=0, control=64, value=127, time=1),
#     Message('note_on', channel=0, note=69, velocity=0, time=206),
#     Message('note_on', channel=0, note=55, velocity=50, time=33),
#     Message('note_on', channel=0, note=67, velocity=46, time=28),
#     Message('note_on', channel=0, note=55, velocity=0, time=52),
#     Message('note_on', channel=0, note=67, velocity=0, time=34),
#     Message('control_change', channel=0, control=64, value=0, time=68),
#     Message('note_on', channel=0, note=62, velocity=47, time=46),
#     Message('note_on', channel=0, note=58, velocity=62, time=6),
#     Message('note_on', channel=0, note=69, velocity=82, time=8),
#     Message('note_on', channel=0, note=51, velocity=61, time=13),
#     Message('note_on', channel=0, note=69, velocity=0, time=182),
#     Message('note_on', channel=0, note=65, velocity=77, time=60),
#     Message('note_on', channel=0, note=65, velocity=0, time=119),
#     Message('note_on', channel=0, note=65, velocity=74, time=78),
#     Message('note_on', channel=0, note=65, velocity=0, time=183),
#     Message('note_on', channel=0, note=58, velocity=0, time=10),
#     Message('note_on', channel=0, note=51, velocity=0, time=36),
#     Message('note_on', channel=0, note=55, velocity=57, time=45),
#     Message('note_on', channel=0, note=62, velocity=0, time=18),
#     Message('note_on', channel=0, note=55, velocity=0, time=64),
#     Message('note_on', channel=0, note=65, velocity=72, time=118),
#     Message('note_on', channel=0, note=58, velocity=73, time=285),
#     Message('note_on', channel=0, note=62, velocity=63, time=1),
#     Message('note_on', channel=0, note=51, velocity=63, time=23),
#     Message('note_on', channel=0, note=58, velocity=0, time=64),
#     Message('note_on', channel=0, note=51, velocity=0, time=17),
#     Message('note_on', channel=0, note=62, velocity=0, time=8),
#     Message('note_on', channel=0, note=58, velocity=65, time=367),
#     Message('note_on', channel=0, note=62, velocity=51, time=5),
#     Message('note_on', channel=0, note=51, velocity=68, time=3),
#     Message('note_on', channel=0, note=58, velocity=0, time=75),
#     Message('note_on', channel=0, note=62, velocity=0, time=18),
#     Message('note_on', channel=0, note=51, velocity=0, time=3),
#     Message('note_on', channel=0, note=51, velocity=73, time=331),
#     Message('note_on', channel=0, note=58, velocity=76, time=7),
#     Message('note_on', channel=0, note=62, velocity=61, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=144),
#     Message('note_on', channel=0, note=51, velocity=0, time=46),
#     Message('note_on', channel=0, note=58, velocity=0, time=5),
#     Message('note_on', channel=0, note=62, velocity=0, time=30),
#     Message('note_on', channel=0, note=51, velocity=74, time=250),
#     Message('note_on', channel=0, note=51, velocity=0, time=58),
#     Message('control_change', channel=0, control=64, value=0, time=5),
#     Message('note_on', channel=0, note=62, velocity=68, time=196),
#     Message('note_on', channel=0, note=57, velocity=60, time=9),
#     Message('note_on', channel=0, note=51, velocity=75, time=5),
#     Message('note_on', channel=0, note=57, velocity=0, time=116),
#     Message('note_on', channel=0, note=62, velocity=0, time=3),
#     Message('note_on', channel=0, note=51, velocity=0, time=7),
#     Message('note_on', channel=0, note=51, velocity=91, time=320),
#     Message('note_on', channel=0, note=62, velocity=72, time=12),
#     Message('note_on', channel=0, note=57, velocity=68, time=9),
#     Message('note_on', channel=0, note=65, velocity=0, time=36),
#     Message('control_change', channel=0, control=64, value=127, time=77),
#     Message('note_on', channel=0, note=57, velocity=0, time=21),
#     Message('note_on', channel=0, note=51, velocity=0, time=30),
#     Message('note_on', channel=0, note=62, velocity=0, time=36),
#     Message('note_on', channel=0, note=70, velocity=114, time=564),
#     Message('note_on', channel=0, note=61, velocity=100, time=5),
#     Message('note_on', channel=0, note=65, velocity=89, time=4),
#     Message('note_on', channel=0, note=56, velocity=86, time=13),
#     Message('control_change', channel=0, control=64, value=0, time=59),
#     Message('note_on', channel=0, note=56, velocity=0, time=188),
#     Message('note_on', channel=0, note=65, velocity=0, time=33),
#     Message('note_on', channel=0, note=70, velocity=0, time=5),
#     Message('note_on', channel=0, note=61, velocity=0, time=2),
#     Message('note_on', channel=0, note=70, velocity=103, time=60),
#     Message('note_on', channel=0, note=61, velocity=84, time=9),
#     Message('note_on', channel=0, note=56, velocity=71, time=10),
#     Message('note_on', channel=0, note=65, velocity=69, time=0),
#     Message('note_on', channel=0, note=56, velocity=0, time=193),
#     Message('note_on', channel=0, note=65, velocity=0, time=22),
#     Message('note_on', channel=0, note=61, velocity=0, time=8),
#     Message('note_on', channel=0, note=70, velocity=0, time=0),
#     Message('note_on', channel=0, note=61, velocity=82, time=75),
#     Message('note_on', channel=0, note=70, velocity=100, time=3),
#     Message('note_on', channel=0, note=65, velocity=74, time=11),
#     Message('note_on', channel=0, note=56, velocity=84, time=10),
#     Message('control_change', channel=0, control=64, value=127, time=231),
#     Message('control_change', channel=0, control=64, value=0, time=55),
#     Message('note_on', channel=0, note=56, velocity=0, time=2),
#     Message('note_on', channel=0, note=65, velocity=0, time=48),
#     Message('note_on', channel=0, note=61, velocity=0, time=5),
#     Message('note_on', channel=0, note=70, velocity=0, time=64),
#     Message('note_on', channel=0, note=68, velocity=83, time=11),
#     Message('note_on', channel=0, note=61, velocity=84, time=11),
#     Message('note_on', channel=0, note=65, velocity=62, time=7),
#     Message('note_on', channel=0, note=56, velocity=61, time=9),
#     Message('control_change', channel=0, control=64, value=127, time=69),
#     Message('note_on', channel=0, note=56, velocity=0, time=32),
#     Message('note_on', channel=0, note=61, velocity=0, time=17),
#     Message('note_on', channel=0, note=65, velocity=0, time=18),
#     Message('note_on', channel=0, note=68, velocity=0, time=17),
#     Message('control_change', channel=0, control=64, value=0, time=29),
#     Message('note_on', channel=0, note=72, velocity=84, time=73),
#     Message('note_on', channel=0, note=60, velocity=61, time=4),
#     Message('note_on', channel=0, note=63, velocity=70, time=22),
#     Message('note_on', channel=0, note=56, velocity=47, time=14),
#     Message('note_on', channel=0, note=63, velocity=0, time=55),
#     Message('note_on', channel=0, note=56, velocity=0, time=23),
#     Message('note_on', channel=0, note=60, velocity=0, time=5),
#     Message('note_on', channel=0, note=72, velocity=0, time=14),
#     Message('note_on', channel=0, note=65, velocity=82, time=305),
#     Message('note_on', channel=0, note=60, velocity=57, time=9),
#     Message('note_on', channel=0, note=63, velocity=66, time=9),
#     Message('note_on', channel=0, note=56, velocity=66, time=6),
#     Message('control_change', channel=0, control=64, value=127, time=123),
#     Message('note_on', channel=0, note=56, velocity=0, time=134),
#     Message('note_on', channel=0, note=63, velocity=0, time=132),
#     Message('note_on', channel=0, note=60, velocity=0, time=10),
#     Message('note_on', channel=0, note=65, velocity=0, time=14),
#     Message('note_on', channel=0, note=56, velocity=35, time=98),
#     Message('note_on', channel=0, note=56, velocity=0, time=60),
#     Message('control_change', channel=0, control=64, value=0, time=45),
#     Message('note_on', channel=0, note=65, velocity=77, time=93),
#     Message('note_on', channel=0, note=63, velocity=66, time=6),
#     Message('note_on', channel=0, note=56, velocity=70, time=7),
#     Message('note_on', channel=0, note=60, velocity=62, time=5),
#     Message('control_change', channel=0, control=64, value=127, time=227),
#     Message('note_on', channel=0, note=65, velocity=0, time=69),
#     Message('note_on', channel=0, note=56, velocity=0, time=70),
#     Message('note_on', channel=0, note=63, velocity=0, time=37),
#     Message('note_on', channel=0, note=60, velocity=0, time=45),
#     Message('note_on', channel=0, note=61, velocity=62, time=462),
#     Message('note_on', channel=0, note=65, velocity=46, time=18),
#     Message('note_on', channel=0, note=56, velocity=57, time=5),
#     Message('control_change', channel=0, control=64, value=0, time=13),
#     Message('note_on', channel=0, note=70, velocity=98, time=256),
#     Message('note_on', channel=0, note=65, velocity=0, time=102),
#     Message('note_on', channel=0, note=70, velocity=0, time=12),
#     Message('note_on', channel=0, note=68, velocity=61, time=358),
#     Message('note_on', channel=0, note=61, velocity=0, time=49),
#     Message('note_on', channel=0, note=56, velocity=0, time=9),
#     Message('note_on', channel=0, note=58, velocity=49, time=20),
#     Message('note_on', channel=0, note=68, velocity=0, time=34),
#     Message('note_on', channel=0, note=58, velocity=0, time=42),
#     Message('note_on', channel=0, note=70, velocity=90, time=78),
#     Message('note_on', channel=0, note=70, velocity=0, time=216),
#     Message('note_on', channel=0, note=68, velocity=55, time=45),
#     Message('note_on', channel=0, note=63, velocity=50, time=35),
#     Message('note_on', channel=0, note=68, velocity=0, time=58),
#     Message('note_on', channel=0, note=63, velocity=0, time=68),
#     Message('note_on', channel=0, note=70, velocity=68, time=28),
#     Message('note_on', channel=0, note=70, velocity=0, time=208),
#     Message('note_on', channel=0, note=70, velocity=60, time=47),
#     Message('note_on', channel=0, note=72, velocity=71, time=132),
#     Message('note_on', channel=0, note=70, velocity=0, time=36),
#     Message('note_on', channel=0, note=58, velocity=74, time=374),
#     Message('note_on', channel=0, note=62, velocity=68, time=0),
#     Message('note_on', channel=0, note=53, velocity=57, time=18),
#     Message('note_on', channel=0, note=58, velocity=0, time=65),
#     Message('note_on', channel=0, note=62, velocity=0, time=11),
#     Message('note_on', channel=0, note=53, velocity=0, time=9),
#     Message('note_on', channel=0, note=56, velocity=49, time=391),
#     Message('note_on', channel=0, note=56, velocity=0, time=66),
#     Message('note_on', channel=0, note=61, velocity=70, time=130),
#     Message('note_on', channel=0, note=58, velocity=67, time=28),
#     Message('note_on', channel=0, note=52, velocity=48, time=28),
#     Message('note_on', channel=0, note=61, velocity=0, time=92),
#     Message('note_on', channel=0, note=58, velocity=0, time=5),
# ...
#     Message('note_on', channel=0, note=64, velocity=51, time=6),
#     Message('note_on', channel=0, note=53, velocity=41, time=15),
#     Message('note_on', channel=0, note=64, velocity=0, time=99),
#     Message('note_on', channel=0, note=60, velocity=0, time=1),
#     Message('note_on', channel=0, note=53, velocity=0, time=66),
#     Message('note_on', channel=0, note=64, velocity=63, time=302),
#     Message('note_on', channel=0, note=60, velocity=52, time=3),
#     Message('note_on', channel=0, note=53, velocity=49, time=11),
#     Message('note_on', channel=0, note=60, velocity=0, time=126),
#     Message('note_on', channel=0, note=64, velocity=0, time=49),
#     Message('note_on', channel=0, note=53, velocity=0, time=17),
#     Message('note_on', channel=0, note=64, velocity=78, time=316),
#     Message('note_on', channel=0, note=59, velocity=69, time=5),
#     Message('note_on', channel=0, note=53, velocity=63, time=9),
#     Message('note_on', channel=0, note=74, velocity=0, time=77),
#     Message('note_on', channel=0, note=80, velocity=112, time=101),
#     Message('note_on', channel=0, note=86, velocity=103, time=10),
#     Message('note_on', channel=0, note=59, velocity=0, time=4),
#     Message('note_on', channel=0, note=53, velocity=0, time=3),
#     Message('note_on', channel=0, note=64, velocity=0, time=6),
#     Message('note_on', channel=0, note=79, velocity=76, time=66),
#     Message('note_on', channel=0, note=80, velocity=0, time=4),
#     Message('note_on', channel=0, note=86, velocity=0, time=155),
#     Message('note_on', channel=0, note=77, velocity=62, time=17),
#     Message('note_on', channel=0, note=79, velocity=0, time=1),
#     Message('note_on', channel=0, note=77, velocity=0, time=147),
#     Message('note_on', channel=0, note=59, velocity=52, time=34),
#     Message('note_on', channel=0, note=64, velocity=53, time=2),
#     Message('note_on', channel=0, note=53, velocity=47, time=9),
#     Message('note_on', channel=0, note=86, velocity=90, time=10),
#     Message('note_on', channel=0, note=79, velocity=81, time=2),
#     Message('note_on', channel=0, note=86, velocity=0, time=211),
#     Message('note_on', channel=0, note=79, velocity=0, time=32),
#     Message('note_on', channel=0, note=81, velocity=86, time=23),
#     Message('note_on', channel=0, note=86, velocity=70, time=22),
#     Message('note_on', channel=0, note=64, velocity=0, time=16),
#     Message('note_on', channel=0, note=53, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=0, time=19),
#     Message('note_on', channel=0, note=86, velocity=0, time=53),
#     Message('note_on', channel=0, note=81, velocity=0, time=53),
#     Message('note_on', channel=0, note=86, velocity=84, time=55),
#     Message('note_on', channel=0, note=79, velocity=82, time=13),
#     Message('note_on', channel=0, note=86, velocity=0, time=136),
#     Message('note_on', channel=0, note=79, velocity=0, time=57),
#     Message('note_on', channel=0, note=77, velocity=64, time=62),
#     Message('note_on', channel=0, note=77, velocity=0, time=173),
#     Message('note_on', channel=0, note=74, velocity=77, time=62),
#     Message('note_on', channel=0, note=74, velocity=0, time=224),
#     Message('note_on', channel=0, note=72, velocity=66, time=31),
#     Message('note_on', channel=0, note=72, velocity=0, time=120),
#     Message('note_on', channel=0, note=60, velocity=55, time=110),
#     Message('note_on', channel=0, note=64, velocity=51, time=0),
#     Message('note_on', channel=0, note=53, velocity=49, time=4),
#     Message('note_on', channel=0, note=74, velocity=75, time=4),
#     Message('note_on', channel=0, note=74, velocity=0, time=208),
#     Message('note_on', channel=0, note=60, velocity=0, time=99),
#     Message('note_on', channel=0, note=64, velocity=0, time=14),
#     Message('note_on', channel=0, note=53, velocity=0, time=13),
#     Message('note_on', channel=0, note=74, velocity=81, time=132),
#     Message('note_on', channel=0, note=60, velocity=59, time=224),
#     Message('note_on', channel=0, note=64, velocity=62, time=5),
#     Message('note_on', channel=0, note=53, velocity=45, time=23),
#     Message('note_on', channel=0, note=60, velocity=0, time=78),
#     Message('note_on', channel=0, note=64, velocity=0, time=18),
#     Message('note_on', channel=0, note=53, velocity=0, time=3),
#     Message('note_on', channel=0, note=74, velocity=0, time=297),
#     Message('note_on', channel=0, note=74, velocity=89, time=111),
#     Message('note_on', channel=0, note=74, velocity=0, time=123),
#     Message('note_on', channel=0, note=74, velocity=82, time=342),
#     Message('note_on', channel=0, note=59, velocity=82, time=473),
#     Message('note_on', channel=0, note=64, velocity=91, time=4),
#     Message('note_on', channel=0, note=53, velocity=80, time=4),
#     Message('note_on', channel=0, note=74, velocity=0, time=92),
#     Message('note_on', channel=0, note=64, velocity=0, time=22),
#     Message('note_on', channel=0, note=59, velocity=0, time=10),
#     Message('note_on', channel=0, note=53, velocity=0, time=30),
#     Message('note_on', channel=0, note=80, velocity=112, time=57),
#     Message('note_on', channel=0, note=86, velocity=107, time=3),
#     Message('note_on', channel=0, note=80, velocity=0, time=107),
#     Message('note_on', channel=0, note=79, velocity=62, time=27),
#     Message('note_on', channel=0, note=86, velocity=0, time=90),
#     Message('note_on', channel=0, note=77, velocity=69, time=13),
#     Message('note_on', channel=0, note=79, velocity=0, time=23),
#     Message('note_on', channel=0, note=77, velocity=0, time=87),
#     Message('note_on', channel=0, note=79, velocity=98, time=116),
#     Message('note_on', channel=0, note=86, velocity=103, time=8),
#     Message('note_on', channel=0, note=79, velocity=0, time=193),
#     Message('note_on', channel=0, note=86, velocity=0, time=7),
#     Message('note_on', channel=0, note=77, velocity=48, time=24),
#     Message('note_on', channel=0, note=77, velocity=0, time=107),
#     Message('note_on', channel=0, note=86, velocity=101, time=94),
#     Message('note_on', channel=0, note=79, velocity=93, time=4),
#     Message('note_on', channel=0, note=86, velocity=0, time=188),
#     Message('note_on', channel=0, note=79, velocity=0, time=29),
#     Message('note_on', channel=0, note=81, velocity=98, time=57),
#     Message('note_on', channel=0, note=86, velocity=90, time=9),
#     Message('note_on', channel=0, note=86, velocity=0, time=183),
#     Message('note_on', channel=0, note=81, velocity=0, time=32),
#     Message('note_on', channel=0, note=60, velocity=61, time=7),
#     Message('note_on', channel=0, note=64, velocity=57, time=13),
#     Message('note_on', channel=0, note=53, velocity=46, time=8),
#     Message('note_on', channel=0, note=79, velocity=119, time=270),
#     Message('note_on', channel=0, note=53, velocity=0, time=57),
#     Message('note_on', channel=0, note=60, velocity=0, time=16),
#     Message('note_on', channel=0, note=64, velocity=0, time=22),
#     Message('note_on', channel=0, note=79, velocity=0, time=101),
#     Message('note_on', channel=0, note=77, velocity=66, time=74),
#     Message('note_on', channel=0, note=77, velocity=0, time=168),
#     Message('note_on', channel=0, note=60, velocity=54, time=60),
#     Message('note_on', channel=0, note=64, velocity=53, time=4),
#     Message('note_on', channel=0, note=74, velocity=73, time=6),
#     Message('note_on', channel=0, note=53, velocity=43, time=6),
#     Message('note_on', channel=0, note=60, velocity=0, time=84),
#     Message('note_on', channel=0, note=64, velocity=0, time=20),
#     Message('note_on', channel=0, note=74, velocity=0, time=24),
#     Message('note_on', channel=0, note=53, velocity=0, time=20),
#     Message('note_on', channel=0, note=72, velocity=82, time=76),
#     Message('note_on', channel=0, note=72, velocity=0, time=192),
#     Message('note_on', channel=0, note=69, velocity=70, time=43),
#     Message('note_on', channel=0, note=69, velocity=0, time=137),
#     Message('note_on', channel=0, note=67, velocity=66, time=69),
#     Message('note_on', channel=0, note=67, velocity=0, time=260),
#     Message('note_on', channel=0, note=59, velocity=50, time=6),
#     Message('note_on', channel=0, note=64, velocity=52, time=4),
#     Message('note_on', channel=0, note=53, velocity=38, time=22),
#     Message('note_on', channel=0, note=65, velocity=60, time=2),
#     Message('note_on', channel=0, note=59, velocity=0, time=81),
#     Message('note_on', channel=0, note=64, velocity=0, time=6),
#     Message('note_on', channel=0, note=65, velocity=0, time=12),
#     Message('note_on', channel=0, note=53, velocity=0, time=59),
#     Message('note_on', channel=0, note=68, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=89, time=14),
#     Message('note_on', channel=0, note=67, velocity=69, time=66),
#     Message('note_on', channel=0, note=68, velocity=0, time=1),
#     Message('note_on', channel=0, note=74, velocity=0, time=127),
#     Message('note_on', channel=0, note=67, velocity=0, time=76),
#     Message('note_on', channel=0, note=65, velocity=38, time=39),
#     Message('note_on', channel=0, note=65, velocity=0, time=161),
#     Message('note_on', channel=0, note=74, velocity=85, time=5),
#     Message('note_on', channel=0, note=67, velocity=72, time=2),
#     Message('note_on', channel=0, note=74, velocity=0, time=189),
#     Message('note_on', channel=0, note=67, velocity=0, time=36),
#     Message('note_on', channel=0, note=69, velocity=88, time=60),
#     Message('note_on', channel=0, note=74, velocity=72, time=3),
#     Message('note_on', channel=0, note=74, velocity=0, time=128),
#     Message('note_on', channel=0, note=69, velocity=0, time=51),
#     Message('note_on', channel=0, note=65, velocity=74, time=45),
#     Message('note_on', channel=0, note=65, velocity=0, time=166),
#     Message('note_on', channel=0, note=62, velocity=66, time=55),
#     Message('note_on', channel=0, note=62, velocity=0, time=152),
#     Message('note_on', channel=0, note=60, velocity=64, time=44),
#     Message('note_on', channel=0, note=60, velocity=0, time=168),
#     Message('note_on', channel=0, note=62, velocity=69, time=324),
#     Message('note_on', channel=0, note=62, velocity=0, time=210),
#     Message('note_on', channel=0, note=60, velocity=50, time=22),
#     Message('note_on', channel=0, note=60, velocity=0, time=98),
#     Message('note_on', channel=0, note=62, velocity=75, time=163),
#     Message('note_on', channel=0, note=60, velocity=51, time=482),
#     Message('note_on', channel=0, note=53, velocity=50, time=11),
#     Message('note_on', channel=0, note=62, velocity=0, time=185),
#     Message('note_on', channel=0, note=62, velocity=76, time=58),
#     Message('note_on', channel=0, note=53, velocity=0, time=89),
#     Message('note_on', channel=0, note=62, velocity=0, time=30),
#     Message('note_on', channel=0, note=60, velocity=0, time=210),
#     Message('note_on', channel=0, note=62, velocity=72, time=132),
#     Message('note_on', channel=0, note=62, velocity=0, time=360),
#     Message('note_on', channel=0, note=59, velocity=68, time=122),
#     Message('note_on', channel=0, note=62, velocity=80, time=12),
#     Message('note_on', channel=0, note=53, velocity=62, time=2),
#     Message('note_on', channel=0, note=59, velocity=0, time=138),
#     Message('note_on', channel=0, note=62, velocity=0, time=41),
#     Message('note_on', channel=0, note=53, velocity=0, time=19),
#     Message('note_on', channel=0, note=65, velocity=94, time=17),
#     Message('note_on', channel=0, note=65, velocity=0, time=181),
#     Message('note_on', channel=0, note=65, velocity=79, time=72),
#     Message('note_on', channel=0, note=59, velocity=11, time=165),
#     Message('note_on', channel=0, note=65, velocity=0, time=14),
#     Message('note_on', channel=0, note=67, velocity=92, time=40),
#     Message('note_on', channel=0, note=59, velocity=0, time=91),
#     Message('note_on', channel=0, note=67, velocity=0, time=109),
#     Message('note_on', channel=0, note=67, velocity=75, time=64),
#     Message('note_on', channel=0, note=67, velocity=0, time=194),
#     Message('note_on', channel=0, note=65, velocity=89, time=39),
#     Message('note_on', channel=0, note=65, velocity=0, time=152),
#     Message('note_on', channel=0, note=65, velocity=65, time=101),
#     Message('note_on', channel=0, note=65, velocity=0, time=181),
#     Message('note_on', channel=0, note=60, velocity=55, time=42),
#     Message('note_on', channel=0, note=53, velocity=46, time=18),
#     Message('note_on', channel=0, note=62, velocity=59, time=1),
#     Message('note_on', channel=0, note=60, velocity=0, time=173),
#     Message('note_on', channel=0, note=53, velocity=0, time=19),
#     Message('note_on', channel=0, note=62, velocity=0, time=31),
#     Message('note_on', channel=0, note=62, velocity=56, time=253),
#     Message('note_on', channel=0, note=53, velocity=42, time=301),
#     Message('note_on', channel=0, note=53, velocity=0, time=82),
#     Message('note_on', channel=0, note=60, velocity=52, time=169),
#     Message('note_on', channel=0, note=53, velocity=49, time=10),
#     Message('note_on', channel=0, note=62, velocity=0, time=33),
#     Message('note_on', channel=0, note=62, velocity=81, time=181),
#     Message('note_on', channel=0, note=53, velocity=0, time=78),
#     Message('note_on', channel=0, note=62, velocity=0, time=162),
#     Message('note_on', channel=0, note=60, velocity=0, time=173),
#     Message('note_on', channel=0, note=68, velocity=115, time=51),
#     Message('note_on', channel=0, note=74, velocity=111, time=3),
#     Message('note_on', channel=0, note=59, velocity=31, time=14),
#     Message('note_on', channel=0, note=53, velocity=32, time=9),
#     Message('note_on', channel=0, note=67, velocity=89, time=32),
#     Message('note_on', channel=0, note=68, velocity=0, time=28),
#     Message('note_on', channel=0, note=59, velocity=0, time=110),
#     Message('note_on', channel=0, note=53, velocity=0, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=0, time=194),
#     Message('note_on', channel=0, note=65, velocity=62, time=20),
#     Message('note_on', channel=0, note=59, velocity=50, time=49),
#     Message('note_on', channel=0, note=53, velocity=37, time=28),
#     Message('note_on', channel=0, note=65, velocity=0, time=77),
#     Message('note_on', channel=0, note=59, velocity=0, time=37),
#     Message('note_on', channel=0, note=74, velocity=72, time=11),
#     Message('note_on', channel=0, note=67, velocity=65, time=8),
#     Message('note_on', channel=0, note=53, velocity=0, time=129),
#     Message('note_on', channel=0, note=74, velocity=0, time=14),
#     Message('note_on', channel=0, note=67, velocity=0, time=36),
#     Message('note_on', channel=0, note=69, velocity=93, time=62),
#     Message('note_on', channel=0, note=74, velocity=85, time=7),
#     Message('note_on', channel=0, note=74, velocity=0, time=157),
#     Message('note_on', channel=0, note=69, velocity=0, time=33),
#     Message('note_on', channel=0, note=65, velocity=72, time=61),
#     Message('note_on', channel=0, note=65, velocity=0, time=169),
#     Message('note_on', channel=0, note=62, velocity=65, time=40),
#     Message('note_on', channel=0, note=62, velocity=0, time=169),
#     Message('note_on', channel=0, note=60, velocity=42, time=75),
#     Message('note_on', channel=0, note=60, velocity=0, time=178),
#     Message('note_on', channel=0, note=53, velocity=48, time=63),
#     Message('note_on', channel=0, note=53, velocity=0, time=108),
#     Message('note_on', channel=0, note=62, velocity=98, time=108),
#     Message('note_on', channel=0, note=60, velocity=88, time=27),
#     Message('note_on', channel=0, note=53, velocity=88, time=5),
#     Message('note_on', channel=0, note=62, velocity=0, time=157),
#     Message('note_on', channel=0, note=60, velocity=0, time=21),
#     Message('note_on', channel=0, note=53, velocity=0, time=8),
#     Message('control_change', channel=0, control=64, value=0, time=1559),
#     MetaMessage('end_of_track', time=1)])
# ])
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)

# %%
songs_list = []
for f in files:
    song = extract(f)
    songs_list.append(song)
# Out:
# ../data/Complete Examples/Oocities/Invitation.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/A Night In Tunisia.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/All Blues.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/All Of Me.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Alone Together (1).mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# ../data/Complete Examples/Oocities/Another You.mid
# ../data/Complete Examples/Oocities/April In Paris.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Black Orpheus.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# ../data/Complete Examples/Oocities/Donna Lee.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Footprints.mid
# ../data/Complete Examples/Oocities/Four.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Give My Regards To Broadway.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# ../data/Complete Examples/Oocities/I Won't Dance.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/In A Sentimental Mood.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pretty_midi/pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# ../data/Complete Examples/Oocities/Israel.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Lazybird.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Maiden Voyage.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Mean To Me.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Meditation.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Misty.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=3, denominator=4, time=0.0)]
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# ../data/Complete Examples/Oocities/New York, New York (2).mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# ../data/Complete Examples/Oocities/One Note Samba.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Peace.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Round Midnight.mid Could not decode key with 6 flats and mode 255
# ../data/Complete Examples/Oocities/Satin Doll.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Secret Love.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Shiny Stockings.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/So What.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Sophisticated Lady.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Stella By Starlight.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# ../data/Complete Examples/Oocities/Take Me Out To The Ball Game.mid [Errno 2] No such file or directory: '../data/Complete Examples Melodies Random/Oocities'
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pretty_midi/pretty_midi.py:97: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# []
# [TimeSignature(numerator=4, denominator=4, time=0.0)]
# [TimeSignature(numerator=4, denominator=4, time=0.0)]

# %%
columns = ['filename', 'source', 'song_name', 'midi_type', 'channels', 
           'n_channels', 'instruments', 'n_instruments', 
           'programs_mido', 'programs_pm', 'melody_tracks', 'melody_track', 
           'melody_track_name', 'candidates', 'candidate_names', 'single_melody', 'multiple_melody', 
           'solo_channel', 'single_candidate', 'multi_channel', 'disagreement', 'status', 'error']
songs = pd.DataFrame(
   songs_list, 
   columns=columns
)

# %%
output_csv = './data/songs/v1.csv'

if not os.path.exists(output_csv):
    songs.to_csv(output_csv)
else:
    print('File already exists!')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_519357/3998520792.py in <module>
#       2
#       3 if not os.path.exists(output_csv):
# ----> 4     songs.to_csv(output_csv)
#       5 else:
#       6     print('File already exists!')
#
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# /media/manu/Data/PycharmProjects/thesis/venv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/songs/v1.csv'

# %%
songs

# %%
songs[songs['error'] == 'program mismatch'][['programs_mido', 'programs_pm']]

# %%
songs[~songs['error'].isnull()]['error'].value_counts()

# %%
songs[~songs.melody_track.isnull()]

# %%
songs[songs.melody_track.isnull()]

# %%
songs[songs.multiple_melody].shape

# %%
songs[(songs.single_melody | songs.solo_channel)]

# %%
songs.shape

# %%
songs.single_melody.value_counts()

# %%
songs.multiple_melody.value_counts()

# %%
songs.solo_channel.value_counts()

# %%
songs.multi_channel.value_counts()

# %%
songs.single_candidate.value_counts()

# %%
songs.disagreement.value_counts()

# %%
songs.error.value_counts()

# %%
songs.status.value_counts()

# %%
songs[songs.status == 'processed']

# %%
unpro = songs[songs.status == 'unprocessed'].head(10)

# %%
songs.melody_track.isnull().sum()
